# %%
import pandas as  pd
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
from sklearn.ensemble import RandomForestClassifier
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Visualize data (each image size (113, 137, 113))

# %%
slice = 50
demo_filepath_whitematter = '/cis/home/jdey4/data_MRI/sub-A00008326/mri/mwp2sub-A00008326_T1w.nii'
demo_filepath_graymatter = '/cis/home/jdey4/data_MRI/sub-A00008326/mri/mwp1sub-A00008326_T1w.nii'

img_whitematter = nb.load(demo_filepath_whitematter).get_fdata()
sliced_img_whitematter = img_whitematter[:,:,slice]

img_graymatter = nb.load(demo_filepath_graymatter).get_fdata()
sliced_img_graymatter = img_graymatter[:,:,slice]

fig, ax = plt.subplots(2,2, figsize=(16,16))
ax[0][0].imshow(sliced_img_whitematter)
ax[0][1].imshow(sliced_img_graymatter)
ax[1][0].hist(sliced_img_whitematter.reshape(-1))
ax[1][1].hist(sliced_img_whitematter.reshape(-1))

ax[0][0].set_title('White matter (Traverse)', fontsize=20)
ax[0][1].set_title('Gray matter (Traverse)', fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/my_documents/cmi/lib/python3.9/site-packages/nibabel/loadsave.py:100, in load(filename, **kwargs)
#      99 try:
# --> 100     stat_result = os.stat(filename)
#     101 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp2sub-A00008326_T1w.nii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 demo_filepath_whitematter = '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp2sub-A00008326_T1w.nii'
#       3 demo_filepath_graymatter = '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp1sub-A00008326_T1w.nii'
# ----> 5 img_whitematter = nb.load(demo_filepath_whitematter).get_fdata()
#       6 sliced_img_whitematter = img_whitematter[:,:,slice]
#       8 img_graymatter = nb.load(demo_filepath_graymatter).get_fdata()
#
# File ~/my_documents/cmi/lib/python3.9/site-packages/nibabel/loadsave.py:102, in load(filename, **kwargs)
#     100     stat_result = os.stat(filename)
#     101 except OSError:
# --> 102     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     103 if stat_result.st_size <= 0:
#     104     raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp2sub-A00008326_T1w.nii'

# %% [markdown]
# ### Analyze class distribution and age

# %%
df = pd.read_excel('/Users/jayantadey/data_MRI/subjects_age_sex_data_MRI.xlsx')
df.head()
# Out:
#                  ID      Age     Sex Dataset Dataset-ID
# 0  sub-ABIDE1050339  18.0000    MALE   ABIDE      50339
# 1  sub-ABIDE1050701  18.0000    MALE   ABIDE      50701
# 2  sub-ABIDE1050445  18.1383    MALE   ABIDE      50445
# 3  sub-ABIDE1050459  18.1547    MALE   ABIDE      50459
# 4  sub-ABIDE1050341  18.2000  FEMALE   ABIDE      50341

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8), sharey=True)

total_female = len(df[df['Sex']=='FEMALE'])
total_male = len(df[df['Sex']=='MALE'])

df[df['Sex']=='FEMALE'].hist(ax=ax[0])
df[df['Sex']=='MALE'].hist(ax=ax[1])

ax[0].set_title('Female ('+str(total_female)+')', fontsize=20)
ax[1].set_title('Male ('+str(total_male)+')', fontsize=20)

ax[0].set_ylabel('Age', fontsize=20)
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# ### Load data and build (feature, label)

# %%
path = '/Users/jayantadey/data_MRI/'
subjects = os.listdir(path)
X = []
y = []
IDs = set(df['ID'])
for subject in subjects:
    if subject in IDs:
        #print(df[df['ID']==subject]['Sex'])
        sex = int(df[df['ID']==subject]['Sex'].item()=='FEMALE')
        current_file = os.path.join(path, subject)
        tmp = []
        save = True
        for file in glob.glob(current_file+'/mri/*'):
            try:
                img = nb.load(file).get_fdata()
                #print(img.shape)
                tmp.append(img.reshape(-1))
            except:
                save = False
                print(file,' corrupted')

        '''if len(tmp)<2:
            print(subject, ' has less files')'''
            
        if save and len(tmp)==2:
            X.append(np.array(tmp).reshape(1,-1))
            y.append(sex)
    else:
        print(subject, " missing")
X = np.concatenate(X,axis=0)
# Out:
# sub-HBN_CBIC_NDARJW697MYZ  missing
# sub-HBN_CBIC_NDARRX084UML  missing
# sub-HBN_CBIC_NDARLR168NP5  missing
# sub-HBN_RU_NDARYX806FL1  missing
# sub-HBN_CUNY_NDARGJ317VC9  missing
# sub-HBN_RU_NDARCB142ZPB  missing
# sub-HBN_CBIC_NDARJK482MZB  missing
# sub-HBN_CBIC_NDARLK690ZK9  missing
# sub-HBN_CBIC_NDARRN996JZK  missing
# sub-HBN_CUNY_NDARXW455MJ1  missing
# sub-HBN_CBIC_NDARJC399UW7  missing
# sub-HBN_RU_NDARHP924ZHW  missing
# sub-HBN_CBIC_NDARAR935TGZ  missing
# sub-HBN_CUNY_NDARUZ408MRL  missing
# sub-HBN_CBIC_NDARUZ221YL6  missing
# sub-HBN_CBIC_NDARCC140AAK  missing
# sub-HBN_CBIC_NDARMX259HUH  missing
# sub-HBN_CBIC_NDARJL656RDA  missing
# sub-HBN_RU_NDARWF259RB2  missing
# sub-HBN_CBIC_NDARAU939WUK  missing
# sub-HBN_CBIC_NDARVV095BWU  missing
# sub-HBN_RU_NDARRK882CLT  missing
# sub-HBN_SI_NDAREE196FEG  missing
# sub-HBN_CBIC_NDARPJ395JDY  missing
# sub-HBN_SI_NDARXE684LUY  missing
# sub-HBN_SI_NDARRK457MBX  missing
# sub-HBN_CBIC_NDARWV826NEC  missing
# sub-HBN_CBIC_NDARWV952EZT  missing
# sub-HBN_RU_NDAREN519BLJ  missing
# sub-HBN_CBIC_NDARJZ167VEZ  missing
# sub-HBN_CUNY_NDARTC795CR3  missing
# sub-HBN_CUNY_NDARTG982TV1  missing
# sub-HBN_CBIC_NDARFB322DRA  missing
# sub-HBN_CBIC_NDARLH881FBD  missing
# sub-HBN_CBIC_NDARVC997CME  missing
# sub-HBN_CBIC_NDAREA788ZAM  missing
# sub-HBN_CUNY_NDARGD751MMW  missing
# sub-HBN_CBIC_NDARRV877ERG  missing
# sub-HBN_CBIC_NDARXB692PXC  missing
# sub-HBN_CBIC_NDARWL758PAM  missing
# sub-HBN_CBIC_NDARWV452YZN  missing
# sub-HBN_RU_NDARFN553LUV  missing
# sub-HBN_RU_NDAREG590BNY  missing
# sub-HBN_CBIC_NDARHX252NVH  missing
# sub-HBN_CUNY_NDARAB282FDJ  missing
# sub-HBN_CBIC_NDARDN090KP6  missing
# sub-HBN_RU_NDARTH473LF8  missing
# sub-HBN_CBIC_NDARDW969AW5  missing
# sub-HBN_CBIC_NDARCH628LKW  missing
# sub-HBN_CUNY_NDARUT650LBR  missing
# sub-HBN_CBIC_NDARVV704MND  missing
# sub-HBN_CBIC_NDARRB561VCP  missing
# sub-HBN_CBIC_NDARBA004KBT  missing
# sub-HBN_RU_NDARKB547TCK  missing
# sub-HBN_CBIC_NDARVJ827RGV  missing
# sub-HBN_CUNY_NDARWC788HHV  missing
# sub-HBN_RU_NDARXZ685TU4  missing
# sub-HBN_CBIC_NDARDZ425JVB  missing
# sub-HBN_CUNY_NDARCP952HZA  missing
# sub-HBN_RU_NDARBU607ZZ3  missing
# sub-HBN_RU_NDARNT113YX7  missing
# sub-HBN_CBIC_NDARKP414AZ5  missing
# sub-HBN_CBIC_NDARCX021XWF  missing
# sub-HBN_CBIC_NDARMV189NXG  missing
# sub-HBN_SI_NDARWF090RZ7  missing
# sub-HBN_RU_NDARZM580BG2  missing
# sub-HBN_RU_NDARGC255BUN  missing
# sub-HBN_RU_NDARZA183DDY  missing
# sub-HBN_CBIC_NDARVG246LT7  missing
# sub-HBN_SI_NDARFW292PBD  missing
# sub-HBN_RU_NDARHM611GDR  missing
# sub-HBN_SI_NDARAV747WVL  missing
# sub-HBN_RU_NDARXG670HFE  missing
# sub-HBN_RU_NDARUJ894ZXG  missing
# sub-HBN_RU_NDARRA717GYV  missing
# sub-HBN_CBIC_NDARXX955UYH  missing
# sub-HBN_RU_NDARAU967RWU  missing
# sub-HBN_RU_NDARDB146NWY  missing
# sub-HBN_RU_NDARFR108JNB  missing
# sub-HBN_CUNY_NDARVD437JV0  missing
# sub-HBN_RU_NDARDL511UND  missing
# sub-HBN_SI_NDARJT730WP0  missing
# sub-HBN_RU_NDARXF203DCD  missing
# sub-HBN_RU_NDARWM848AKP  missing
# sub-HBN_RU_NDARYY218LU2  missing
# sub-HBN_CUNY_NDARCT531TC0  missing
# sub-HBN_CBIC_NDARKN477EBH  missing
# sub-HBN_RU_NDARFL506HVX  missing
# sub-HBN_RU_NDARTZ018PD5  missing
# sub-HBN_CUNY_NDARYK236YUD  missing
# sub-HBN_CUNY_NDARTG982UC3  missing
# sub-HBN_RU_NDARMY254BGN  missing
# sub-HBN_CUNY_NDARAY665GWN  missing
# sub-HBN_RU_NDARXL588FFJ  missing
# sub-HBN_RU_NDARUG091CY1  missing
# sub-HBN_RU_NDARMV718DYL  missing
# sub-HBN_CBIC_NDARFP503KJF  missing
# sub-HBN_CBIC_NDARWW790AKX  missing
# sub-HBN_RU_NDARPP726XBF  missing
# sub-HBN_RU_NDARGR354WBH  missing
# sub-HBN_CBIC_NDARLT294VUD  missing
# sub-HBN_CBIC_NDARRA321UKA  missing
# sub-HBN_SI_NDARHL358LGQ  missing
# sub-HBN_RU_NDARHZ476MJP  missing
# sub-HBN_CUNY_NDARTT476DAT  missing
# sub-HBN_CUNY_NDARUZ859WCN  missing
# sub-HBN_CBIC_NDARZH930XTP  missing
# sub-HBN_CBIC_NDARLV812JXX  missing
# sub-HBN_RU_NDARUG859NKB  missing
# sub-HBN_CBIC_NDARLJ970DEY  missing
# sub-HBN_CBIC_NDARAE839XXL  missing
# sub-HBN_CUNY_NDARUM301RDE  missing
# sub-HBN_CUNY_NDARJW691ZFR  missing
# sub-HBN_RU_NDARCK661RZ6  missing
# sub-HBN_CUNY_NDARYK657ZLC  missing
# sub-HBN_RU_NDARCJ363KLE  missing
# sub-HBN_CBIC_NDARWE818UA6  missing
# sub-HBN_CBIC_NDARER318CE4  missing
# sub-HBN_SI_NDARAA536PTU  missing
# sub-HBN_SI_NDARTU768MY1  missing
# sub-HBN_CUNY_NDARMT473DZV  missing
# sub-HBN_CBIC_NDARRA719CPH  missing
# sub-HBN_RU_NDARGC170UK2  missing
# sub-HBN_CBIC_NDARLM196YRG  missing
# sub-HBN_CBIC_NDARFG943GVZ  missing
# sub-HBN_RU_NDARPH844KP2  missing
# sub-HBN_RU_NDARCG073GZ6  missing
# sub-HBN_RU_NDARPJ691NEU  missing
# sub-HBN_CUNY_NDARPT665ADN  missing
# sub-HBN_RU_NDARXH597ML1  missing
# sub-HBN_RU_NDARBF805EHN  missing
# sub-HBN_RU_NDARZD985LU8  missing
# sub-HBN_CBIC_NDARWE229HBY  missing
# sub-HBN_CBIC_NDAREB629FVB  missing
# sub-HBN_RU_NDARAC495TJ2  missing
# sub-HBN_RU_NDARAH503YG1  missing
# sub-HBN_RU_NDARNP423EJQ  missing
# sub-HBN_RU_NDARAF440XWG  missing
# sub-HBN_CBIC_NDARAC350BZ0  missing
# sub-HBN_RU_NDARRP801AX1  missing
# sub-HBN_CUNY_NDARVR636CY5  missing
# sub-HBN_CBIC_NDARMP494MYD  missing
# sub-HBN_CBIC_NDARRP317WAP  missing
# sub-HBN_RU_NDARPU897CM5  missing
# sub-HBN_CBIC_NDARBH502NZ9  missing
# sub-HBN_RU_NDARRG199RU4  missing
# sub-HBN_CBIC_NDARUF236HM7  missing
# sub-HBN_CBIC_NDARRZ640EG2  missing
# sub-HBN_CBIC_NDARXX939FFN  missing
# sub-HBN_CBIC_NDARWC174VE6  missing
# sub-HBN_CUNY_NDARDX173WLD  missing
# sub-HBN_CUNY_NDARZN702ECL  missing
# sub-HBN_CUNY_NDARLL176DJR  missing
# sub-HBN_CBIC_NDARUP000VHQ  missing
# sub-HBN_CBIC_NDARMT151RNN  missing
# sub-HBN_CBIC_NDARYC287UFV  missing
# sub-HBN_CBIC_NDARLY771XJ0  missing
# sub-HBN_SI_NDARHZ439EBY  missing
# sub-HBN_CBIC_NDARJK147LNJ  missing
# sub-HBN_CBIC_NDARAN934AZL  missing
# sub-HBN_SI_NDARHW216PER  missing
# sub-HBN_RU_NDARTB294NF0  missing
# sub-HBN_CUNY_NDARVC745RL3  missing
# sub-HBN_CUNY_NDARAX431KJ2  missing
# sub-HBN_CUNY_NDARPU981GWF  missing
# sub-HBN_CUNY_NDARNK156GLD  missing
# sub-HBN_CBIC_NDARXD907ZJL  missing
# sub-HBN_CBIC_NDARVL498YX5  missing
# sub-HBN_CBIC_NDARMX196KKY  missing
# sub-HBN_CBIC_NDARFC286KV1  missing
# sub-HBN_CBIC_NDAREG930XPP  missing
# sub-HBN_RU_NDAREW937RMY  missing
# sub-HBN_CUNY_NDARHN638ET1  missing
# sub-HBN_RU_NDARAD224CRB  missing
# sub-HBN_CBIC_NDARFW140WFX  missing
# sub-HBN_RU_NDARMT784NED  missing
# sub-HBN_CBIC_NDARDT308PP4  missing
# sub-HBN_CBIC_NDARYD958HAX  missing
# sub-HBN_CBIC_NDARUM624FW7  missing
# sub-HBN_RU_NDARNK740ZVM  missing
# sub-HBN_CBIC_NDARDC003YG7  missing
# sub-HBN_RU_NDARJM296MDW  missing
# sub-HBN_SI_NDARKR195PL9  missing
# sub-HBN_CUNY_NDARGY200NTW  missing
# sub-HBN_CUNY_NDARFR630AAD  missing
# sub-HBN_RU_NDARCJ170CT9  missing
# sub-HBN_CBIC_NDARGP669PKX  missing
# sub-HBN_CBIC_NDARZU401RCU  missing
# sub-HBN_SI_NDARWJ087HKJ  missing
# sub-HBN_RU_NDARGY559UL3  missing
# sub-HBN_RU_NDARFK610GY5  missing
# sub-HBN_CUNY_NDARBP713ZWA  missing
# sub-HBN_RU_NDARKJ546WWQ  missing
# sub-HBN_SI_NDARTY625VHZ  missing
# sub-HBN_CUNY_NDARDE769PHW  missing
# sub-HBN_RU_NDARKH444AGK  missing
# sub-HBN_RU_NDARCJ475WJP  missing
# sub-HBN_CUNY_NDARFJ087KP2  missing
# sub-HBN_CBIC_NDARDY883WN6  missing
# sub-HBN_CBIC_NDARKW010CT2  missing
# sub-HBN_RU_NDARHH757RT9  missing
# sub-HBN_CBIC_NDARYH697TPA  missing
# sub-HBN_CBIC_NDARLH365ZUD  missing
# sub-HBN_CBIC_NDARTH065GZ0  missing
# sub-HBN_CBIC_NDARYE155BLQ  missing
# sub-HBN_CBIC_NDARUD871XPD  missing
# sub-HBN_CUNY_NDARNP836NUY  missing
# sub-HBN_RU_NDARDZ528DLZ  missing
# sub-HBN_CUNY_NDARNF439YDW  missing
# sub-HBN_CUNY_NDARLD071YA7  missing
# sub-HBN_RU_NDARVG808PKQ  missing
# sub-HBN_SI_NDARAK187ZLP  missing
# sub-HBN_CUNY_NDARZC028AEC  missing
# sub-HBN_CBIC_NDARPC356JKP  missing
# sub-HBN_RU_NDARCU417HRA  missing
# sub-HBN_RU_NDARJH910CGX  missing
# sub-HBN_CBIC_NDARGT409NJZ  missing
# sub-HBN_CBIC_NDARCU891YET  missing
# sub-HBN_RU_NDARGH634ME7  missing
# sub-HBN_CBIC_NDARUA745NA8  missing
# sub-HBN_CBIC_NDARNL887YUJ  missing
# sub-HBN_RU_NDARXU715EGL  missing
# sub-HBN_CUNY_NDAREL027FPB  missing
# sub-HBN_CUNY_NDARKN742LEV  missing
# sub-HBN_SI_NDARGE366WNC  missing
# sub-HBN_RU_NDARDZ010EDH  missing
# sub-HBN_CUNY_NDARLM981MEN  missing
# sub-HBN_RU_NDARNB674VMY  missing
# sub-HBN_RU_NDARVV199XK2  missing
# sub-HBN_RU_NDARAD571FLB  missing
# sub-HBN_RU_NDARHC737MHK  missing
# sub-HBN_RU_NDAREW671HZW  missing
# sub-HBN_RU_NDARVY366HWJ  missing
# sub-HBN_CUNY_NDARPW746FWF  missing
# sub-HBN_CBIC_NDARLW774VY1  missing
# sub-HBN_RU_NDARZD099KWW  missing
# sub-HBN_CBIC_NDARZL162HZH  missing
# sub-HBN_CBIC_NDAREE675XRY  missing
# sub-HBN_CBIC_NDARCJ246FJB  missing
# sub-HBN_RU_NDARTC652JK4  missing
# sub-HBN_RU_NDARWP675DHU  missing
# sub-HBN_CBIC_NDARLU274CC7  missing
# sub-HBN_CUNY_NDARCF658ZMQ  missing
# sub-HBN_CBIC_NDARXL053AW6  missing
# sub-HBN_CUNY_NDARNX583ELQ  missing
# sub-HBN_CBIC_NDARMX842MTR  missing
# sub-HBN_RU_NDARKM497VKX  missing
# sub-HBN_RU_NDARKX665ZD3  missing
# sub-HBN_CBIC_NDARFB969EMV  missing
# sub-HBN_CUNY_NDARGY058YX2  missing
# sub-HBN_RU_NDARVN270UU2  missing
# sub-HBN_RU_NDARWE130JMG  missing
# sub-HBN_CBIC_NDARWU936JGG  missing
# sub-HBN_CBIC_NDARTC802PGL  missing
# sub-HBN_CBIC_NDARWE001EAY  missing
# sub-HBN_CBIC_NDARKM476GFK  missing
# sub-HBN_CBIC_NDARBG605BAR  missing
# sub-HBN_CBIC_NDARCA214DMT  missing
# sub-HBN_CBIC_NDARRC959DHC  missing
# sub-HBN_RU_NDARUC715YN4  missing
# sub-HBN_SI_NDARWV155PRG  missing
# sub-HBN_CBIC_NDARWM632AFC  missing
# sub-HBN_CBIC_NDARVD543CMZ  missing
# sub-HBN_CBIC_NDARFG757CEU  missing
# sub-HBN_SI_NDARZB377WZJ  missing
# sub-HBN_CBIC_NDARRY768ZH3  missing
# sub-HBN_CUNY_NDARYJ413BLN  missing
# sub-HBN_RU_NDARYU345GZJ  missing
# sub-HBN_SI_NDARKM551DA4  missing
# sub-HBN_CBIC_NDARCX505WVX  missing
# sub-HBN_CBIC_NDARRY126FA5  missing
# sub-HBN_CBIC_NDARUV041YCY  missing
# sub-HBN_RU_NDARPW635LN4  missing
# sub-HBN_RU_NDARPL201YL4  missing
# sub-HBN_CUNY_NDARNC405WJA  missing
# sub-HBN_CBIC_NDARUG126FUY  missing
# sub-HBN_RU_NDARPV009TYX  missing
# sub-HBN_RU_NDARFA815FXE  missing
# sub-HBN_SI_NDARED047DTH  missing
# sub-HBN_RU_NDARLD287MLP  missing
# sub-HBN_CBIC_NDARWM929URT  missing
# sub-HBN_CBIC_NDARUY720JW1  missing
# sub-HBN_RU_NDARMT064WBB  missing
# sub-HBN_CBIC_NDARDN229AKK  missing
# sub-HBN_CUNY_NDARFU218HYM  missing
# sub-HBN_CUNY_NDARRP961CC7  missing
# sub-HBN_CBIC_NDARKL694YEM  missing
# sub-HBN_CBIC_NDAREE177WUM  missing
# sub-HBN_CBIC_NDAREU073NFU  missing
# sub-HBN_CUNY_NDARRH574YPF  missing
# sub-HBN_CBIC_NDARNF362NU0  missing
# sub-HBN_CBIC_NDARKD124UHN  missing
# sub-HBN_CBIC_NDARFK947HD9  missing
# sub-HBN_RU_NDARMZ200GVD  missing
# sub-HBN_CUNY_NDARAZ069DBL  missing
# sub-HBN_RU_NDARYF368WEA  missing
# sub-HBN_RU_NDARKY667THK  missing
# sub-HBN_RU_NDARLF480DMW  missing
# sub-HBN_CBIC_NDAREU890CYJ  missing
# sub-HBN_RU_NDARLL572UP2  missing
# sub-HBN_SI_NDARBM213BEA  missing
# sub-HBN_SI_NDARFU789PRX  missing
# sub-HBN_SI_NDARKA429EPF  missing
# sub-HBN_RU_NDARYF338WW1  missing
# sub-HBN_SI_NDARFN452VPC  missing
# sub-HBN_CUNY_NDARPZ078XCK  missing
# sub-HBN_CBIC_NDARRA981BCM  missing
# sub-HBN_CBIC_NDARHV831DRH  missing
# sub-HBN_CBIC_NDARDY714NV9  missing
# sub-HBN_RU_NDARZV895RZ5  missing
# sub-HBN_CBIC_NDARHK843RUL  missing
# sub-HBN_CBIC_NDARHP417RH8  missing
# sub-HBN_CBIC_NDARWC819TRH  missing
# sub-HBN_RU_NDARXY240WJC  missing
# sub-HBN_CBIC_NDARUL454XRE  missing
# sub-HBN_SI_NDARMZ908DUR  missing
# sub-HBN_RU_NDARVC821LP9  missing
# sub-HBN_CUNY_NDARYB099EL3  missing
# sub-HBN_RU_NDARCW094JCG  missing
# sub-HBN_RU_NDARCU118LMX  missing
# sub-HBN_CBIC_NDARPP255LGE  missing
# sub-HBN_CUNY_NDARKL778XGD  missing
# sub-HBN_CBIC_NDARLV708XXF  missing
# sub-HBN_CUNY_NDARWE850WRP  missing
# sub-HBN_RU_NDARWH779MZ2  missing
# sub-HBN_CBIC_NDARNP254RWE  missing
# sub-HBN_CBIC_NDARVD748TR8  missing
# sub-HBN_CBIC_NDARTM499DC9  missing
# sub-HBN_CUNY_NDARXG035ZVM  missing
# sub-HBN_RU_NDARHF351AA6  missing
# sub-HBN_CBIC_NDARJL016LRL  missing
# sub-HBN_RU_NDARMX277VHC  missing
# sub-HBN_RU_NDARBR740NKV  missing
# sub-HBN_CBIC_NDARJU025FPW  missing
# sub-HBN_RU_NDARHZ814MHQ  missing
# sub-HBN_RU_NDARUF170ABA  missing
# sub-HBN_RU_NDARTH433TE0  missing
# sub-HBN_RU_NDARVY859ENR  missing
# sub-HBN_SI_NDARFA464HJQ  missing
# sub-HBN_CBIC_NDARNB032ZLC  missing
# sub-HBN_CBIC_NDARCP057XJB  missing
# sub-HBN_RU_NDARVB842ZM8  missing
# sub-HBN_CUNY_NDAREY366VH0  missing
# sub-HBN_CBIC_NDARAM873GAC  missing
# sub-HBN_RU_NDARTK933KL9  missing
# sub-HBN_CUNY_NDARXE944JP7  missing
# sub-HBN_CUNY_NDARDW147PAZ  missing
# sub-HBN_CBIC_NDARDM119WB1  missing
# sub-HBN_CBIC_NDARZW619BDL  missing
# sub-HBN_CBIC_NDARTB266RP5  missing
# sub-HBN_CBIC_NDARXJ452HAJ  missing
# sub-HBN_RU_NDARYA556KP8  missing
# sub-HBN_SI_NDARPD977VX2  missing
# sub-HBN_CUNY_NDARCD182XT1  missing
# sub-HBN_CUNY_NDARAP748AWX  missing
# sub-HBN_CUNY_NDARJW888AJ2  missing
# sub-HBN_RU_NDARJB236XDY  missing
# sub-HBN_CBIC_NDARKC993YWF  missing
# sub-HBN_CBIC_NDARMT461DNB  missing
# sub-HBN_CBIC_NDARBW320UFW  missing
# sub-HBN_CBIC_NDARPT670LAY  missing
# sub-HBN_RU_NDARXU253JHC  missing
# sub-HBN_RU_NDARBW026UGE  missing
# sub-HBN_CUNY_NDARVB091TPK  missing
# sub-HBN_CUNY_NDARVA284CL4  missing
# sub-HBN_CUNY_NDARNV187AMZ  missing
# sub-HBN_RU_NDARKW521EMY  missing
# sub-HBN_CBIC_NDARPJ763DV1  missing
# sub-HBN_CBIC_NDARWT989KPJ  missing
# sub-HBN_CBIC_NDARFT615JZ6  missing
# sub-HBN_CBIC_NDARHC814ZZL  missing
# sub-HBN_CUNY_NDARRA523JDG  missing
# sub-HBN_CBIC_NDARRG973HJQ  missing
# sub-HBN_RU_NDARDX872VH6  missing
# sub-HBN_CUNY_NDARRK528GFZ  missing
# sub-HBN_CBIC_NDARGN210CK7  missing
# sub-HBN_CBIC_NDARCA618DGA  missing
# sub-HBN_CUNY_NDARCW058DP8  missing
# sub-HBN_CUNY_NDARCY741VVX  missing
# sub-HBN_RU_NDARDP786HE6  missing
# sub-HBN_CBIC_NDARJE254CVV  missing
# sub-HBN_RU_NDARYR150UDP  missing
# sub-HBN_RU_NDARRV002MA8  missing
# sub-HBN_RU_NDARPF395NV5  missing
# sub-HBN_RU_NDARZU822WN3  missing
# sub-HBN_RU_NDARPT777FDA  missing
# sub-HBN_CBIC_NDARFN854EJB  missing
# sub-HBN_CBIC_NDAREZ060XH6  missing
# sub-HBN_RU_NDARMN376BMF  missing
# sub-HBN_CUNY_NDARHV358ZCU  missing
# sub-HBN_CBIC_NDARGG423UMK  missing
# sub-HBN_CBIC_NDARWZ553VDB  missing
# sub-HBN_RU_NDARWG200CUE  missing
# sub-HBN_CBIC_NDARVC964LX0  missing
# sub-HBN_CBIC_NDARTT867NWT  missing
# sub-HBN_CBIC_NDARTK667PGK  missing
# sub-HBN_CUNY_NDARYU719EPL  missing
# sub-HBN_CUNY_NDARGG442NML  missing
# sub-HBN_CUNY_NDARDK635CD2  missing
# sub-HBN_RU_NDARMM326JCB  missing
# sub-HBN_CUNY_NDARYV571RJJ  missing
# sub-HBN_CBIC_NDARCC340ER5  missing
# sub-HBN_RU_NDARBE123PWH  missing
# sub-HBN_RU_NDARRV097NU1  missing
# sub-HBN_CBIC_NDARRT039CPB  missing
# sub-HBN_RU_NDARJB366HYJ  missing
# sub-HBN_RU_NDARPZ973RK0  missing
# sub-HBN_CBIC_NDARRW643DHJ  missing
# sub-HBN_RU_NDARHC357HLP  missing
# sub-HBN_CBIC_NDARGN499DJ5  missing
# sub-HBN_CBIC_NDARAY021PPD  missing
# sub-HBN_RU_NDARZK753WGR  missing
# sub-HBN_SI_NDARBB854DRN  missing
# sub-HBN_CBIC_NDARLA457ELH  missing
# sub-HBN_RU_NDARTB300BN3  missing
# sub-HBN_CBIC_NDARAG644KE3  missing
# sub-HBN_CBIC_NDARXE912NZP  missing
# sub-HBN_CBIC_NDARTE580DV0  missing
# sub-HBN_CBIC_NDARWB042HCE  missing
# sub-HBN_CBIC_NDARUM009GEZ  missing
# sub-HBN_CBIC_NDARHY471CA6  missing
# sub-HBN_SI_NDARNF954MK3  missing
# sub-HBN_RU_NDARYR829KD8  missing
# sub-HBN_CBIC_NDARGR199PM2  missing
# sub-HBN_CBIC_NDARZA115BW6  missing
# sub-HBN_CBIC_NDARHX628PC6  missing
# sub-HBN_SI_NDARXJ696AMX  missing
# sub-HBN_CBIC_NDAREA724CZR  missing
# sub-HBN_CBIC_NDARYA807PVN  missing
# sub-HBN_CBIC_NDAREE845YW9  missing
# sub-HBN_CBIC_NDARGH842VFY  missing
# sub-HBN_CUNY_NDARWM620AX5  missing
# sub-HBN_CBIC_NDARHH127PCL  missing
# sub-HBN_CUNY_NDARDV550JB2  missing
# sub-HBN_CUNY_NDARAW909KL9  missing
# sub-HBN_RU_NDARDC843HHM  missing
# sub-HBN_SI_NDARHM273AXL  missing
# sub-HBN_RU_NDARKA946MJ1  missing
# sub-HBN_CBIC_NDARNA335GX2  missing
# sub-HBN_RU_NDAREV527ZRF  missing
# sub-HBN_CBIC_NDARVX111CNA  missing
# sub-HBN_CBIC_NDARMB857WG7  missing
# sub-HBN_CBIC_NDARGN460JU2  missing
# sub-HBN_CUNY_NDARUZ795GRG  missing
# sub-HBN_RU_NDARRC190NKB  missing
# sub-HBN_CUNY_NDARCC491MHH  missing
# sub-HBN_CUNY_NDARRN880XA0  missing
# sub-HBN_CBIC_NDAREG872WYW  missing
# sub-HBN_SI_NDARCA789EE0  missing
# sub-HBN_CBIC_NDARFB146TG0  missing
# sub-HBN_RU_NDARMH559LKK  missing
# sub-HBN_CBIC_NDARUX368CL6  missing
# sub-HBN_RU_NDARJB027GMR  missing
# sub-HBN_SI_NDARME656MTN  missing
# sub-HBN_CUNY_NDARZB904CDB  missing
# sub-HBN_CBIC_NDARMF846EVR  missing
# sub-HBN_CBIC_NDARPU049CJ7  missing
# sub-HBN_CBIC_NDARNM721XWT  missing
# sub-HBN_CBIC_NDARTF317KRD  missing
# sub-HBN_CBIC_NDAREG104JB1  missing
# sub-HBN_CBIC_NDARVF159VP9  missing
# sub-HBN_RU_NDARKF363RN1  missing
# sub-HBN_SI_NDARYP495KFK  missing
# sub-HBN_RU_NDARAK738BGC  missing
# sub-HBN_CUNY_NDARAD269FZD  missing
# sub-HBN_RU_NDARYC594EHN  missing
# sub-HBN_RU_NDARLN961XGP  missing
# sub-HBN_CBIC_NDARVD552PRC  missing
# sub-HBN_CBIC_NDARNF873FCV  missing
# sub-HBN_RU_NDARUL224GN6  missing
# sub-HBN_CBIC_NDARZV749GAP  missing
# sub-HBN_CBIC_NDARPA917PE9  missing
# sub-HBN_RU_NDARGX760NYV  missing
# sub-HBN_RU_NDARGN044FE4  missing
# sub-HBN_RU_NDARUJ744NEU  missing
# sub-HBN_SI_NDARNV332JF2  missing
# sub-HBN_CUNY_NDARLT946JYZ  missing
# sub-HBN_RU_NDARUA832MYV  missing
# sub-HBN_RU_NDARYZ637LK4  missing
# sub-HBN_CBIC_NDARRZ993EL4  missing
# sub-HBN_RU_NDARFX455JFY  missing
# sub-HBN_SI_NDARVJ504DAA  missing
# sub-HBN_CBIC_NDARZB128KCF  missing
# sub-HBN_CUNY_NDARVK467GCK  missing
# sub-HBN_CUNY_NDARHA652HR1  missing
# sub-HBN_CBIC_NDARGP984YLN  missing
# sub-HBN_RU_NDARHG065YHQ  missing
# sub-HBN_CBIC_NDARKK153GT7  missing
# sub-HBN_RU_NDARNU137XR4  missing
# sub-HBN_CUNY_NDARWL656URE  missing
# sub-HBN_CBIC_NDARCM050BN2  missing
# sub-HBN_RU_NDARLE871HNP  missing
# sub-HBN_CBIC_NDARTU280GKF  missing
# sub-HBN_CUNY_NDARKF767BNC  missing
# sub-HBN_CBIC_NDARDA656RBN  missing
# sub-HBN_RU_NDARMB290GPL  missing
# sub-HBN_RU_NDARUM791WPF  missing
# sub-HBN_RU_NDARRH285LR3  missing
# sub-HBN_CUNY_NDARDW463WFD  missing
# sub-HBN_RU_NDARUF540ZJ1  missing
# sub-HBN_RU_NDARWN885MGD  missing
# sub-HBN_RU_NDARYJ334EHH  missing
# sub-HBN_CUNY_NDARCG464RH2  missing
# sub-HBN_CBIC_NDARWV938NKD  missing
# sub-HBN_CBIC_NDARLK551KXD  missing
# sub-HBN_CUNY_NDARZA147PC7  missing
# sub-HBN_SI_NDARWW901MTC  missing
# sub-HBN_RU_NDARWK051GG4  missing
# sub-HBN_CBIC_NDARVT648BWF  missing
# sub-HBN_RU_NDARYG546ZFF  missing
# sub-HBN_CBIC_NDAREV869CPW  missing
# sub-HBN_RU_NDARYD195BDH  missing
# sub-HBN_CBIC_NDARKV309YFH  missing
# sub-HBN_RU_NDARFM328XW4  missing
# sub-HBN_CUNY_NDARTG706ZV8  missing
# sub-HBN_RU_NDAREX589EXG  missing
# sub-HBN_CUNY_NDARDT550XYX  missing
# sub-HBN_CBIC_NDARKE153NEM  missing
# sub-HBN_RU_NDARTL336THT  missing
# sub-HBN_RU_NDARXR965TFK  missing
# sub-HBN_RU_NDARUX216VHK  missing
# sub-HBN_CBIC_NDAREX336AC1  missing
# sub-HBN_RU_NDARFD552FRH  missing
# sub-HBN_CBIC_NDARWE938FWQ  missing
# sub-HBN_RU_NDARJD235KZA  missing
# sub-HBN_CBIC_NDARBC202FT0  missing
# sub-HBN_CBIC_NDARWM955GR5  missing
# sub-HBN_CBIC_NDARRP609JH2  missing
# sub-HBN_CUNY_NDARKD168VHJ  missing
# sub-HBN_CBIC_NDARYD256DZR  missing
# sub-HBN_RU_NDARYC243UW5  missing
# sub-HBN_RU_NDARVC716GEE  missing
# sub-HBN_RU_NDARFR301KKP  missing
# sub-HBN_CUNY_NDARJE271DMC  missing
# sub-HBN_CBIC_NDARBR128UFP  missing
# sub-HBN_RU_NDARDR458MR7  missing
# sub-HBN_CBIC_NDARHV423JV3  missing
# sub-HBN_CBIC_NDARAW620GJ8  missing
# sub-HBN_RU_NDARGH775KF5  missing
# sub-HBN_CBIC_NDARUD637TU2  missing
# sub-HBN_CBIC_NDARDP495PY2  missing
# sub-HBN_RU_NDARZE850WXD  missing
# sub-HBN_CBIC_NDARRX138MLG  missing
# sub-HBN_CBIC_NDARYX965RWP  missing
# sub-HBN_RU_NDARWV405ZW0  missing
# sub-HBN_CBIC_NDARPM002AXQ  missing
# sub-HBN_SI_NDARRA733VWX  missing
# sub-HBN_RU_NDARNT205ZKP  missing
# sub-HBN_RU_NDARVX162AZU  missing
# sub-HBN_CBIC_NDARJF579EH9  missing
# sub-HBN_CBIC_NDARBJ478HW5  missing
# sub-HBN_SI_NDARDA695XTL  missing
# sub-HBN_CBIC_NDARFG364YMG  missing
# sub-HBN_CUNY_NDARUX070CWZ  missing
# sub-HBN_CBIC_NDARKF899ZUB  missing
# sub-HBN_CBIC_NDARZF170TZ0  missing
# sub-HBN_CUNY_NDARFV289RKB  missing
# sub-HBN_RU_NDARAY475AKD  missing
# sub-HBN_RU_NDARXG995EV6  missing
# sub-HBN_CBIC_NDARNK489GNR  missing
# sub-HBN_CBIC_NDARVB151GXF  missing
# sub-HBN_RU_NDARBX974XDR  missing
# sub-HBN_CBIC_NDARWL486MKR  missing
# sub-HBN_SI_NDARMV247HRA  missing
# sub-HBN_CBIC_NDARPX661BF1  missing
# sub-HBN_CUNY_NDARFC694PW2  missing
# sub-HBN_CBIC_NDARVN370YL8  missing
# sub-HBN_CBIC_NDARVV769EZ8  missing
# sub-HBN_CBIC_NDARXJ125LXZ  missing
# sub-HBN_RU_NDARAH948UF0  missing
# sub-HBN_CBIC_NDARGK059JW7  missing
# sub-HBN_RU_NDARHR372GJ7  missing
# sub-HBN_RU_NDARKB614KGY  missing
# sub-HBN_CBIC_NDARJA737FAJ  missing
# sub-HBN_RU_NDARMP977RHZ  missing
# sub-HBN_CBIC_NDARTZ403MC0  missing
# sub-HBN_CBIC_NDARAV925BP3  missing
# sub-HBN_SI_NDARXH017ZLE  missing
# sub-HBN_SI_NDARDK983BDA  missing
# sub-HBN_CBIC_NDARPH152GU1  missing
# sub-HBN_CUNY_NDARHT518WEM  missing
# sub-HBN_CBIC_NDARAM197GFY  missing
# sub-HBN_CBIC_NDARNZ141GNH  missing
# sub-HBN_RU_NDARXT822TAA  missing
# sub-HBN_CBIC_NDARCT420MW1  missing
# sub-HBN_CBIC_NDARCV628NRY  missing
# sub-HBN_SI_NDARMC412BCK  missing
# sub-HBN_SI_NDARLL389TUF  missing
# sub-HBN_CBIC_NDARHW933UVJ  missing
# sub-HBN_RU_NDARTZ901LDK  missing
# sub-HBN_CUNY_NDARRT854TMV  missing
# sub-HBN_SI_NDARHB781DD8  missing
# sub-HBN_RU_NDARRA767WB7  missing
# sub-HBN_CBIC_NDARWC399JLD  missing
# sub-HBN_CBIC_NDARPF937BDQ  missing
# sub-HBN_CUNY_NDARGY639ANB  missing
# sub-HBN_CBIC_NDARFM811ZCE  missing
# sub-HBN_CUNY_NDARJK487UCN  missing
# sub-HBN_CBIC_NDARYN474PEK  missing
# sub-HBN_RU_NDARCV440TRV  missing
# sub-HBN_CBIC_NDARFD620BUW  missing
# sub-HBN_CBIC_NDARKJ743AE4  missing
# sub-HBN_CBIC_NDARKC978MR4  missing
# sub-HBN_CBIC_NDARDC553RE2  missing
# sub-HBN_CBIC_NDARNB905CFU  missing
# sub-HBN_CBIC_NDARPN886HH9  missing
# sub-HBN_RU_NDARWE908KF8  missing
# sub-HBN_SI_NDARZP564MHU  missing
# sub-HBN_RU_NDARMA449JDZ  missing
# sub-HBN_RU_NDARAC853DTE  missing
# sub-HBN_CUNY_NDARRM475LGX  missing
# sub-HBN_CUNY_NDARYC834ML4  missing
# sub-HBN_CUNY_NDARVU223DDB  missing
# sub-HBN_RU_NDARXG767MTB  missing
# sub-HBN_CBIC_NDARJT173MR1  missing
# sub-HBN_CBIC_NDARDN089RX5  missing
# sub-HBN_CBIC_NDARLJ728JY2  missing
# sub-HBN_RU_NDARBM490LK7  missing
# sub-HBN_RU_NDARBL935ZUA  missing
# sub-HBN_RU_NDARZH672BAM  missing
# sub-HBN_RU_NDARUU991VRE  missing
# sub-HBN_CBIC_NDARKX528PH3  missing
# sub-HBN_RU_NDARJT523MV7  missing
# sub-HBN_RU_NDARKH837TB2  missing
# sub-HBN_CBIC_NDARZX745YLZ  missing
# sub-HBN_CBIC_NDARFY525TL2  missing
# sub-HBN_RU_NDARMT732GKM  missing
# sub-HBN_CBIC_NDARBG188RA5  missing
# sub-HBN_RU_NDARKE726AMA  missing
# sub-HBN_CBIC_NDARAK770XEW  missing
# sub-HBN_CBIC_NDARXE242KMQ  missing
# sub-HBN_CBIC_NDARBG073ZY4  missing
# .DS_Store  missing
# sub-HBN_RU_NDARMZ119VPH  missing
# sub-HBN_RU_NDARBG831VK4  missing
# sub-HBN_CUNY_NDAREC447FDH  missing
# sub-HBN_CBIC_NDARFZ477RC8  missing
# sub-HBN_CUNY_NDARMZ096TBD  missing
# sub-HBN_RU_NDARDX665TKP  missing
# sub-HBN_CUNY_NDARLV704BPE  missing
# sub-HBN_CBIC_NDARBM764KG0  missing
# sub-HBN_CBIC_NDARZU751VBU  missing
# sub-HBN_CBIC_NDARUZ818ADU  missing
# sub-HBN_SI_NDARPG072ZZ7  missing
# sub-HBN_RU_NDARDW416KWZ  missing
# sub-HBN_CBIC_NDARDC814WW2  missing
# sub-HBN_SI_NDARUT792WX7  missing
# sub-HBN_RU_NDARDZ147ETZ  missing
# sub-HBN_CBIC_NDARVC874KGR  missing
# sub-HBN_SI_NDARUM569EV1  missing
# sub-HBN_CUNY_NDARND445LCA  missing
# sub-HBN_CBIC_NDARBP398JHL  missing
# sub-HBN_CBIC_NDARCU736GZ1  missing
# sub-HBN_SI_NDARVG436WGG  missing
# sub-HBN_RU_NDARXR637JER  missing
# sub-HBN_CBIC_NDARFC188VT4  missing
# sub-HBN_RU_NDARTE785ZMJ  missing
# sub-HBN_CUNY_NDARER805TNZ  missing
# sub-HBN_CUNY_NDARNW188JTF  missing
# sub-HBN_CBIC_NDARUU939VRT  missing
# sub-HBN_CBIC_NDARKT593WDF  missing
# sub-HBN_RU_NDARGA815EUZ  missing
# sub-HBN_CUNY_NDARKD245CN0  missing
# sub-HBN_CUNY_NDARPP694XU9  missing
# sub-HBN_CBIC_NDARKG460MWV  missing
# sub-HBN_RU_NDARJW072UJ3  missing
# sub-HBN_CUNY_NDARPB578JMT  missing
# sub-HBN_RU_NDARKA085YRG  missing
# sub-HBN_CBIC_NDARXR123PFR  missing
# sub-HBN_RU_NDARGZ038DRL  missing
# sub-HBN_CUNY_NDARCA146GG1  missing
# sub-HBN_CBIC_NDARPG387YY2  missing
# sub-HBN_RU_NDARWF514TW5  missing
# sub-HBN_CUNY_NDARPL440BX5  missing
# sub-HBN_RU_NDARJH99CWH  missing
# sub-HBN_RU_NDARER970AEF  missing
# sub-HBN_CBIC_NDARDK794WV3  missing
# sub-HBN_CUNY_NDARBZ149ELP  missing
# sub-HBN_CBIC_NDARZY959NH2  missing
# sub-HBN_CUNY_NDARUA035YJN  missing
# sub-HBN_RU_NDAREM609ZXW  missing
# sub-HBN_RU_NDAREP505XAD  missing
# sub-HBN_CBIC_NDARNJ623KAF  missing
# sub-HBN_CBIC_NDARVB877VWL  missing
# sub-HBN_CUNY_NDARZA982YTP  missing
# sub-HBN_CUNY_NDARZR968TLL  missing
# sub-HBN_RU_NDARJT517YHZ  missing
# sub-HBN_CBIC_NDARBK638HLZ  missing
# sub-HBN_CUNY_NDARVX769HEQ  missing
# sub-HBN_CBIC_NDARFP100DJL  missing
# sub-HBN_CBIC_NDARVE086HX4  missing
# sub-HBN_RU_NDARYZ906UHJ  missing
# sub-HBN_CUNY_NDARUR627UZG  missing
# sub-HBN_RU_NDARNK768THB  missing
# sub-HBN_CUNY_NDARDW550GU6  missing
# sub-HBN_CUNY_NDARNT317BE2  missing
# sub-HBN_CBIC_NDARDR406DZ7  missing
# sub-HBN_RU_NDAREF164ZUJ  missing
# sub-HBN_SI_NDARET949LMU  missing
# sub-HBN_RU_NDARXH529MTX  missing
# sub-HBN_CBIC_NDAREN691WTC  missing
# sub-HBN_CBIC_NDARLY114PDC  missing
# sub-HBN_CBIC_NDARXL697DA6  missing
# sub-HBN_RU_NDARCV981XUY  missing
# sub-HBN_RU_NDAREF893ZM8  missing
# sub-HBN_CBIC_NDARFG851ZNZ  missing
# sub-HBN_RU_NDARXU018RGY  missing
# sub-HBN_CBIC_NDARKP895CJG  missing
# sub-HBN_CBIC_NDARDH086ZKK  missing
# sub-HBN_RU_NDARMX328VWC  missing
# sub-HBN_RU_NDARWJ321WKG  missing
# sub-HBN_RU_NDAREC480KFA  missing
# sub-HBN_CBIC_NDARZX163EWC  missing
# sub-HBN_CBIC_NDARGA890MKA  missing
# sub-HBN_CBIC_NDARGD414MUA  missing
# sub-HBN_CUNY_NDARMU228TCQ  missing
# sub-HBN_CBIC_NDARYT332LMM  missing
# sub-HBN_CBIC_NDARCB062WP0  missing
# sub-HBN_CBIC_NDARUC771VM5  missing
# sub-HBN_CBIC_NDARRH694YCJ  missing
# sub-HBN_RU_NDARCK647MU6  missing
# sub-HBN_CUNY_NDARAF628ND6  missing
# sub-HBN_CBIC_NDARZW873DN3  missing
# sub-HBN_RU_NDARVB897AH1  missing
# sub-HBN_RU_NDARMC694YF3  missing
# sub-HBN_RU_NDARMJ495DE0  missing
# sub-HBN_CBIC_NDARLY125HMB  missing
# sub-HBN_RU_NDAREC648WEL  missing
# sub-HBN_CBIC_NDARUB069LMP  missing
# sub-HBN_RU_NDARJG740PM8  missing
# sub-HBN_CBIC_NDARZN914GPB  missing
# sub-HBN_CBIC_NDARUX818MGE  missing
# sub-HBN_CBIC_NDAREL410HHK  missing
# sub-HBN_CBIC_NDARTC177RN5  missing
# sub-HBN_SI_NDARKX761BH9  missing
# sub-HBN_CBIC_NDARXK254YD2  missing
# sub-HBN_CUNY_NDARTD443ZUB  missing
# sub-HBN_CBIC_NDARBG819PT9  missing
# sub-HBN_RU_NDARCX053GU5  missing
# sub-HBN_CBIC_NDARZR700EG6  missing
# sub-HBN_RU_NDARKK392ZX2  missing
# sub-HBN_CBIC_NDARJU056AA1  missing
# sub-HBN_RU_NDARNN142WYB  missing
# sub-HBN_RU_NDARNX125KJ1  missing
# sub-HBN_CBIC_NDARWR624NF4  missing
# sub-HBN_RU_NDARCA116GH8  missing
# sub-HBN_CBIC_NDARXV291ATY  missing
# sub-HBN_SI_NDARKX346VTV  missing
# sub-HBN_CBIC_NDARKM568HJK  missing
# sub-HBN_CBIC_NDARJU530TZN  missing
# sub-HBN_RU_NDARUV263YB5  missing
# sub-HBN_CUNY_NDARTZ495EMX  missing
# sub-HBN_CBIC_NDARBZ925PRF  missing
# sub-HBN_SI_NDARDN770HY6  missing
# sub-HBN_SI_NDARHR944BBY  missing
# sub-HBN_CBIC_NDARMM594VJT  missing
# sub-HBN_CUNY_NDAREA860NEX  missing
# sub-HBN_CBIC_NDARML514ZFM  missing
# sub-HBN_CBIC_NDARXY532ZTT  missing
# sub-HBN_RU_NDARYY419ZXX  missing
# sub-HBN_CBIC_NDARBY041JPE  missing
# sub-HBN_RU_NDARXF358XGE  missing
# sub-HBN_CBIC_NDARRK545WNM  missing
# sub-HBN_CBIC_NDARVG777EUZ  missing
# sub-HBN_RU_NDARXU883NMY  missing
# sub-HBN_CBIC_NDARUP441BKK  missing
# sub-HBN_CBIC_NDARAD703XA2  missing
# sub-HBN_CBIC_NDARUH340WL5  missing
# sub-HBN_RU_NDARCK481KRH  missing
# sub-HBN_CBIC_NDARJG086ZMJ  missing
# sub-HBN_CBIC_NDARBD582TDT  missing
# sub-HBN_RU_NDARLX836EHJ  missing
# sub-HBN_CBIC_NDARAH373VWM  missing
# sub-HBN_RU_NDARNV694EMG  missing
# sub-HBN_CUNY_NDARZB799GAK  missing
# sub-HBN_CBIC_NDARXY277ND0  missing
# sub-HBN_RU_NDARJZ679KXJ  missing
# sub-HBN_SI_NDARNM624PDC  missing
# sub-HBN_RU_NDARTG035JK8  missing
# sub-HBN_CBIC_NDARYL090TGH  missing
# sub-HBN_CBIC_NDARRK038CBD  missing
# sub-HBN_CUNY_NDARFL595DNJ  missing
# sub-HBN_RU_NDARWA433WYZ  missing
# sub-HBN_RU_NDARKF779EK2  missing
# sub-HBN_CBIC_NDARNH743HW0  missing
# sub-HBN_CUNY_NDARAB678VYW  missing
# sub-HBN_CBIC_NDARNZ084JVC  missing
# sub-HBN_CBIC_NDARVM326HYM  missing
# sub-HBN_CBIC_NDARUP735CM8  missing
# sub-HBN_CBIC_NDARNM384EEW  missing
# sub-HBN_CBIC_NDARRV688GUX  missing
# sub-HBN_CUNY_NDARNR347UB9  missing
# sub-HBN_CUNY_NDARDC665WJQ  missing
# sub-HBN_SI_NDARMM990URX  missing
# sub-HBN_RU_NDARTA819MF0  missing
# sub-HBN_CBIC_NDARNB130EX2  missing
# sub-HBN_CBIC_NDARPH022TRY  missing
# sub-HBN_RU_NDARWF306VWJ  missing
# sub-HBN_CUNY_NDARGD229DCJ  missing
# sub-HBN_CUNY_NDARYH224RXX  missing
# sub-HBN_RU_NDARTT242GNN  missing
# sub-HBN_CBIC_NDARWW480TU2  missing
# sub-HBN_CBIC_NDARVY378DFK  missing
# sub-HBN_RU_NDARPZ344ZGE  missing
# sub-HBN_RU_NDARVL697YGK  missing
# sub-HBN_CUNY_NDARBK487AYA  missing
# sub-HBN_RU_NDARWP157RYM  missing
# sub-HBN_CBIC_NDARBE912PB0  missing
# sub-HBN_RU_NDARHT095YB4  missing
# sub-HBN_CBIC_NDARAB458VK9  missing
# sub-HBN_RU_NDARMU518TVN  missing
# sub-HBN_CBIC_NDARCJ108KNZ  missing
# sub-HBN_RU_NDARPD568LHV  missing
# sub-HBN_CUNY_NDARCN681CXW  missing
# sub-HBN_CBIC_NDARYK772JH8  missing
# sub-HBN_RU_NDARLJ472DLM  missing
# sub-HBN_CBIC_NDARTH612TJM  missing
# sub-HBN_CBIC_NDARDH868WEB  missing
# sub-HBN_CBIC_NDARPL651MD5  missing
# sub-HBN_RU_NDARBV577EE0  missing
# sub-HBN_RU_NDARJG821GH3  missing
# sub-HBN_CBIC_NDARBP770MUM  missing
# sub-HBN_RU_NDARBC734UVY  missing
# sub-HBN_RU_NDARVG597HNL  missing
# sub-HBN_CBIC_NDARAY461TZZ  missing
# sub-HBN_CUNY_NDARHP895ZWL  missing
# sub-HBN_RU_NDARWC426HEA  missing
# sub-HBN_CBIC_NDAREE075BGN  missing
# sub-HBN_CBIC_NDARMZ366UY8  missing
# sub-HBN_CUNY_NDARHY571VGY  missing
# sub-HBN_CUNY_NDARWC905XUG  missing
# sub-HBN_RU_NDARVJ687ENB  missing
# sub-HBN_RU_NDARJV377HG4  missing
# sub-HBN_CBIC_NDARDL305BT8  missing
# sub-HBN_CBIC_NDARFE372VHL  missing
# sub-HBN_RU_NDARGL936KTV  missing
# sub-HBN_CUNY_NDARUF588WT6  missing
# sub-HBN_CBIC_NDARMV674TJY  missing
# sub-HBN_CBIC_NDARFY623ZTE  missing
# sub-HBN_CBIC_NDARKZ085UKQ  missing
# sub-HBN_CBIC_NDARNV124WR8  missing
# sub-HBN_CBIC_NDARAG191AE8  missing
# sub-HBN_CBIC_NDARKB878YNG  missing
# sub-HBN_CBIC_NDARDJ544BU5  missing
# sub-HBN_RU_NDARCJ433TCG  missing
# sub-HBN_SI_NDARHF904CWB  missing
# sub-HBN_CBIC_NDAREM356FXV  missing
# sub-HBN_RU_NDARTW855BPJ  missing
# sub-HBN_RU_NDARAP522AFK  missing
# sub-HBN_CBIC_NDARAH976BND  missing
# sub-HBN_CUNY_NDARZA561GFF  missing
# sub-HBN_CBIC_NDARXM551CTE  missing
# sub-HBN_CBIC_NDARGJ145ZK8  missing
# sub-HBN_CBIC_NDARNT093XMB  missing
# sub-HBN_RU_NDARFG568PXZ  missing
# sub-HBN_CUNY_NDARZU576KZD  missing
# sub-HBN_CUNY_NDARCC909PYL  missing
# sub-HBN_CBIC_NDARPL598MVU  missing
# sub-HBN_CBIC_NDARBF575JUL  missing
# sub-HBN_RU_NDARRU720LG4  missing
# sub-HBN_SI_NDARMM878ZR1  missing
# sub-HBN_RU_NDARMX482GWR  missing
# sub-HBN_CUNY_NDARMK299CN4  missing
# sub-HBN_CBIC_NDARDY312BR2  missing
# sub-HBN_RU_NDARRP384BVX  missing
# sub-HBN_CUNY_NDARPH340DKQ  missing
# sub-HBN_CUNY_NDARWK605KC3  missing
# sub-HBN_CBIC_NDARMZ518UH1  missing
# sub-HBN_CBIC_NDARNL926VB7  missing
# sub-HBN_SI_NDAREF057VX5  missing
# sub-HBN_RU_NDAREU551GPC  missing
# sub-HBN_CUNY_NDARPV412JEN  missing
# sub-HBN_CBIC_NDARTZ842BUW  missing
# sub-HBN_RU_NDARCA578CEB  missing
# sub-HBN_CBIC_NDARYA845EGP  missing
# sub-HBN_RU_NDARWA351ZE2  missing
# sub-HBN_RU_NDARNM783ZVV  missing
# sub-HBN_RU_NDARPK597XH0  missing
# sub-HBN_RU_NDARLY483UNZ  missing
# sub-HBN_CUNY_NDARFP841PDJ  missing
# sub-HBN_CBIC_NDARRL315KV3  missing
# sub-HBN_CUNY_NDARVN772GLC  missing
# sub-HBN_CBIC_NDARYB483HY0  missing
# sub-HBN_CBIC_NDARDD073JKZ  missing
# sub-HBN_CBIC_NDAREU591YYA  missing
# sub-HBN_CBIC_NDARPR799VX4  missing
# sub-HBN_RU_NDARWA513WM2  missing
# sub-HBN_RU_NDARWG798MJG  missing
# sub-HBN_RU_NDARRX552PP2  missing
# sub-HBN_CUNY_NDARXJ540FP7  missing
# sub-HBN_CUNY_NDARPL263BJZ  missing
# sub-HBN_CBIC_NDARCL201KJZ  missing
# sub-HBN_RU_NDARNE196LV0  missing
# sub-HBN_CBIC_NDARXP021FZ5  missing
# sub-HBN_CBIC_NDARRB403PDE  missing
# sub-HBN_RU_NDARUW904FMQ  missing
# sub-HBN_CBIC_NDARDY421HTK  missing
# sub-HBN_CBIC_NDARNA055LLN  missing
# sub-HBN_CUNY_NDARXC266NHY  missing
# sub-HBN_SI_NDARFB500HHN  missing
# sub-HBN_SI_NDAREL063PMX  missing
# sub-HBN_CBIC_NDARGB528CP8  missing
# sub-HBN_CUNY_NDARBX443ZLU  missing
# sub-HBN_CUNY_NDARDH753GUF  missing
# sub-HBN_CBIC_NDARWG549LCF  missing
# sub-HBN_RU_NDARTE432ZRH  missing
# sub-HBN_SI_NDARJX421FWR  missing
# sub-HBN_RU_NDARBV630BK6  missing
# sub-HBN_CBIC_NDARLP425JYL  missing
# sub-HBN_RU_NDARLY585ZVN  missing
# sub-HBN_CUNY_NDARDH871DWE  missing
# sub-HBN_CBIC_NDARAG429CGW  missing
# sub-HBN_CBIC_NDARVJ394TEC  missing
# sub-HBN_CBIC_NDARFG027BT5  missing
# sub-HBN_CBIC_NDARAN229MTX  missing
# sub-HBN_CBIC_NDARHH819LH3  missing
# sub-HBN_SI_NDARXF956ZU6  missing
# sub-HBN_RU_NDARXT256FRP  missing
# sub-HBN_RU_NDARYZ693DE2  missing
# sub-HBN_CBIC_NDARKM250ET5  missing
# sub-HBN_CBIC_NDARVN280JTN  missing
# sub-HBN_CBIC_NDARLN749FML  missing
# sub-HBN_CBIC_NDARFR601RDQ  missing
# sub-HBN_SI_NDARWJ019VGU  missing
# sub-HBN_RU_NDARKU616UBL  missing
# sub-HBN_SI_NDARDX469TC1  missing
# sub-HBN_CBIC_NDARJH492TVW  missing
# sub-HBN_CBIC_NDARTN483XE4  missing
# sub-HBN_CBIC_NDARLG918MG8  missing
# sub-HBN_RU_NDARYY022HBW  missing
# sub-HBN_RU_NDARLL894HC3  missing
# sub-HBN_CUNY_NDARXL801JVG  missing
# sub-HBN_RU_NDARNE406XC3  missing
# sub-HBN_CUNY_NDAREL0366HL  missing
# sub-HBN_CBIC_NDARWX605LAD  missing
# sub-HBN_CBIC_NDARMF450DKQ  missing
# sub-HBN_CBIC_NDARYA857NDW  missing
# sub-HBN_CUNY_NDARRR570MC0  missing
# sub-HBN_CBIC_NDARVN883AU2  missing
# sub-HBN_CUNY_NDARXH863ZXA  missing
# sub-HBN_CUNY_NDARND375WF5  missing
# sub-HBN_CBIC_NDARTJ433TB5  missing
# sub-HBN_CBIC_NDARUL290YKN  missing
# sub-HBN_CBIC_NDARTB203DU7  missing
# sub-HBN_CBIC_NDARHR751MTT  missing
# sub-HBN_RU_NDAREC078VFT  missing
# sub-HBN_CBIC_NDARVB902GA5  missing
# sub-HBN_CUNY_NDARMX051HZM  missing
# sub-HBN_CBIC_NDARWV091RWT  missing
# sub-HBN_CUNY_NDARZR293TKN  missing
# sub-HBN_RU_NDARGK041TPB  missing
# sub-HBN_CBIC_NDARYG988PUQ  missing
# sub-HBN_RU_NDARKM635UY0  missing
# sub-HBN_CBIC_NDARLC770YL9  missing
# sub-HBN_CUNY_NDARZT581RNV  missing
# sub-HBN_RU_NDARMZ687XRR  missing
# sub-HBN_RU_NDARCB627KDN  missing
# sub-HBN_CBIC_NDARVK847ZRT  missing
# sub-HBN_CUNY_NDAREL751LME  missing
# sub-HBN_CUNY_NDARMW299ZAB  missing
# sub-HBN_RU_NDARDR591AUC  missing
# sub-HBN_CBIC_NDARTE773XJ5  missing
# sub-HBN_CUNY_NDARBL990KHP  missing
# sub-HBN_RU_NDARGB441VVD  missing
# sub-HBN_RU_NDARGE536BGD  missing
# sub-HBN_CBIC_NDARVC711ZK0  missing
# sub-HBN_RU_NDARAJ689BVN  missing
# sub-HBN_RU_NDARCZ947WU5  missing
# sub-HBN_CBIC_NDARBZ913ZB9  missing
# sub-HBN_CBIC_NDARDF374LGN  missing
# sub-HBN_CUNY_NDARAP120HTA  missing
# sub-HBN_CBIC_NDARNZ433DDH  missing
# sub-HBN_CUNY_NDARWF545PCM  missing
# sub-HBN_CBIC_NDARHR386KRJ  missing
# sub-HBN_CUNY_NDARLK762JFX  missing
# sub-HBN_CUNY_NDARAC589YMB  missing
# sub-HBN_RU_NDARWJ498CZY  missing
# sub-HBN_CBIC_NDARBH789CUP  missing
# sub-HBN_RU_NDARUL675RXW  missing
# sub-HBN_CBIC_NDARTF720AGD  missing
# sub-HBN_CUNY_NDARAU044FP6  missing
# sub-HBN_CUNY_NDARKR658HW2  missing
# sub-HBN_CBIC_NDARNW528VXP  missing
# sub-HBN_SI_NDARLF283KJX  missing
# sub-HBN_CBIC_NDARAH793FBF  missing
# sub-HBN_CUNY_NDARRJ938NT7  missing
# sub-HBN_RU_NDARKH298MA3  missing
# sub-HBN_CBIC_NDARNZ015EK8  missing
# sub-HBN_CBIC_NDARUM721FCJ  missing
# sub-HBN_RU_NDARWP954GPJ  missing
# sub-HBN_CUNY_NDARDU500JTQ  missing
# sub-HBN_CUNY_NDARZZ046HJA  missing
# sub-HBN_CBIC_NDARJJ512AYJ  missing
# sub-HBN_CBIC_NDARTF781TM8  missing
# sub-HBN_CBIC_NDARFM619GTV  missing
# sub-HBN_CUNY_NDARAG943DF9  missing
# sub-HBN_RU_NDARYR994ELB  missing
# sub-HBN_RU_NDARWK983JFE  missing
# sub-HBN_RU_NDARDN996CPF  missing
# sub-HBN_RU_NDARHJ830RXD  missing
# sub-HBN_CUNY_NDARKG951TXD  missing
# sub-HBN_SI_NDAREB290UCN  missing
# sub-HBN_CBIC_NDARFJ803JF7  missing
# sub-HBN_CBIC_NDARPH637HAZ  missing
# sub-HBN_RU_NDARNZ610KZY  missing
# sub-HBN_CBIC_NDARCV606ZZ5  missing
# sub-HBN_CBIC_NDAREC238AY4  missing
# sub-HBN_CUNY_NDARMX215YPN  missing
# sub-HBN_SI_NDARMU269TFY  missing
# sub-HBN_CBIC_NDARXT081TEU  missing
# sub-HBN_RU_NDARJ257ZU2  missing
# sub-HBN_CBIC_NDARGC148JBJ  missing
# sub-HBN_CBIC_NDARNK139XNA  missing
# sub-HBN_CBIC_NDARUH016MWG  missing
# sub-HBN_RU_NDARND348HB3  missing
# sub-HBN_RU_NDARJF755DT9  missing
# sub-HBN_RU_NDARFT176NJP  missing
# sub-HBN_CBIC_NDARWV984WMM  missing
# sub-HBN_CBIC_NDARMD666RYJ  missing
# sub-HBN_RU_NDARLG154ZA3  missing
# sub-HBN_RU_NDARHN911CNJ  missing
# sub-HBN_CBIC_NDARRE445RHR  missing
# sub-HBN_RU_NDARKV965WLU  missing
# sub-HBN_CUNY_NDARZM839GHH  missing
# sub-HBN_RU_NDARHM421JUP  missing
# sub-HBN_CUNY_NDARFP601KKC  missing
# sub-HBN_RU_NDARAU708TL8  missing
# sub-HBN_RU_NDARBV059CGE  missing
# sub-HBN_RU_NDARJW315BUA  missing
# sub-HBN_CBIC_NDARNA768ZAK  missing
# sub-HBN_CBIC_NDARPY458LTR  missing
# sub-HBN_CUNY_NDARRF073YV1  missing
# sub-HBN_CBIC_NDARBU532YXZ  missing
# sub-HBN_RU_NDARLJ334YD0  missing
# sub-HBN_CBIC_NDARDL033XRG  missing
# sub-HBN_CBIC_NDARBF851NH6  missing
# sub-HBN_CBIC_NDARGM426CJT  missing
# sub-HBN_CBIC_NDARYD265AZN  missing
# sub-HBN_CBIC_NDARAG788YV9  missing
# sub-HBN_CBIC_NDARRC935ATQ  missing
# sub-HBN_RU_NDARTN760YH8  missing
# sub-HBN_CBIC_NDARJT921KTH  missing
# sub-HBN_SI_NDARNJ715JPV  missing
# sub-HBN_CBIC_NDARKW511VE6  missing
# sub-HBN_CBIC_NDARDJ872BYV  missing
# sub-HBN_RU_NDARVA930UA3  missing
# sub-HBN_CBIC_NDARVC350WVG  missing
# sub-HBN_CBIC_NDARRU560AGK  missing
# sub-HBN_CBIC_NDARZT957CWG  missing
# sub-HBN_CBIC_NDARLK158UN6  missing
# sub-HBN_SI_NDARCV412MDW  missing
# sub-HBN_CBIC_NDARZU279XR3  missing
# sub-HBN_CBIC_NDARFJ179MG0  missing
# sub-HBN_RU_NDARAW179AYF  missing
# sub-HBN_CBIC_NDARRH251ECK  missing
# sub-HBN_SI_NDARVM685MER  missing
# sub-HBN_RU_NDARXY938XY7  missing
# sub-HBN_CBIC_NDARCT277WK9  missing
# sub-HBN_SI_NDARYU620RH9  missing
# sub-HBN_CBIC_NDARFR445XKP  missing
# sub-HBN_CBIC_NDARCZ236ERR  missing
# sub-HBN_CBIC_NDARZL113CU0  missing
# sub-HBN_CBIC_NDARVP894EX0  missing
# sub-HBN_RU_NDARWM527PRT  missing
# sub-HBN_CBIC_NDARHD017XEU  missing
# sub-HBN_CBIC_NDARAA504CRN  missing
# sub-HBN_RU_NDARGV781AMW  missing
# sub-HBN_RU_NDARFW578RU9  missing
# sub-HBN_CBIC_NDARER136KZ5  missing
# sub-HBN_SI_NDARKR010EN7  missing
# sub-HBN_RU_NDARDG747ULB  missing
# sub-HBN_RU_NDARTU777GVV  missing
# sub-HBN_CBIC_NDARBC865CXQ  missing
# sub-HBN_CBIC_NDARVN363NNQ  missing
# sub-HBN_CUNY_NDARHR789EVF  missing
# sub-HBN_CBIC_NDAREB953UMY  missing
# sub-HBN_CUNY_NDARPP238VMX  missing
# sub-HBN_SI_NDARJJ356DAL  missing
# sub-HBN_CUNY_NDARPC418NZL  missing
# sub-HBN_CUNY_NDARKM388MHN  missing
# sub-HBN_RU_NDARUP908XUJ  missing
# sub-HBN_CUNY_NDARNN493WMD  missing
# sub-HBN_CBIC_NDARPB044UXA  missing
# sub-HBN_CUNY_NDARHY346GY2  missing
# sub-HBN_RU_NDARJB233RL7  missing
# sub-HBN_CBIC_NDAREM757NBG  missing
# sub-HBN_CBIC_NDARBY976XYY  missing
# sub-HBN_RU_NDARUG492VF0  missing
# sub-HBN_CBIC_NDARGM421YWQ  missing
# sub-HBN_CUNY_NDARRW259YBX  missing
# sub-HBN_SI_NDARZF288FB7  missing
# sub-HBN_CBIC_NDARLA788EWU  missing
# sub-HBN_CUNY_NDARPZ327PDV  missing
# sub-HBN_CBIC_NDARGT623ZBY  missing
# sub-HBN_CUNY_NDARZA879DJG  missing
# sub-HBN_CUNY_NDARMU461UD4  missing
# sub-HBN_CUNY_NDARVU647ED2  missing
# sub-HBN_CBIC_NDARRD460FZE  missing
# sub-HBN_CBIC_NDARRA428WB9  missing
# sub-HBN_CBIC_NDARWG820RKE  missing
# sub-HBN_CBIC_NDARDD193HUP  missing
# sub-HBN_SI_NDARAA075AMK  missing
# sub-HBN_CBIC_NDARKH264PPJ  missing
# sub-HBN_CBIC_NDARGB817AHC  missing
# sub-HBN_SI_NDARHE236YLB  missing
# sub-HBN_RU_NDARWN691CG7  missing
# sub-HBN_RU_NDARYU898ETS  missing
# sub-HBN_SI_NDAREM018TJQ  missing
# sub-HBN_SI_NDARUD764NFJ  missing
# sub-HBN_CBIC_NDARMM431GVE  missing
# sub-HBN_CUNY_NDARAU517MC6  missing
# sub-HBN_CBIC_NDARMT126PB3  missing
# sub-HBN_SI_NDARWB943YY9  missing
# sub-HBN_CBIC_NDARHR558BNN  missing
# sub-HBN_RU_NDARYL758JGG  missing
# sub-HBN_RU_NDARWU876CWH  missing
# sub-HBN_CBIC_NDARVP838PLC  missing
# sub-HBN_CUNY_NDARFX879UEY  missing
# sub-HBN_RU_NDARDH214UVC  missing
# sub-HBN_RU_NDARFR095UJK  missing
# sub-HBN_RU_NDARJT588ZAX  missing
# sub-HBN_RU_NDARGL800LDW  missing
# sub-HBN_RU_NDARUK054GTN  missing
# sub-HBN_RU_NDARLD016VCA  missing
# sub-HBN_CUNY_NDAREX726VYV  missing
# sub-HBN_RU_NDARJV268PNW  missing
# sub-HBN_RU_NDARLN070VX7  missing
# sub-HBN_CBIC_NDARMA584EM0  missing
# sub-HBN_CBIC_NDARGN782BZN  missing
# sub-HBN_RU_NDARWV568MEU  missing
# sub-HBN_CBIC_NDARNP921JTV  missing
# sub-HBN_RU_NDARMP745EAC  missing
# sub-HBN_CBIC_NDARDM027XFE  missing
# sub-HBN_CBIC_NDARDM156AVJ  missing
# sub-HBN_CBIC_NDARUK025ZFT  missing
# sub-HBN_CBIC_NDARVU320XJZ  missing
# sub-HBN_RU_NDARMN302YAV  missing
# sub-HBN_RU_NDARKN346XZH  missing
# sub-HBN_CBIC_NDARHV915YXJ  missing
# sub-HBN_CUNY_NDARVV437NF6  missing
# sub-HBN_SI_NDARFW130NGG  missing
# sub-HBN_SI_NDARVE724GEF  missing
# sub-HBN_RU_NDARBL242L4H  missing
# sub-HBN_CBIC_NDAREK395BM3  missing
# sub-HBN_CBIC_NDARDR439HY2  missing
# sub-HBN_CBIC_NDARRZ145TFN  missing
# sub-HBN_CBIC_NDARDX196MZP  missing
# sub-HBN_SI_NDARJR525HTX  missing
# sub-HBN_CUNY_NDARHD100UMG  missing
# sub-HBN_RU_NDARCG037CX4  missing
# sub-HBN_SI_NDARNB440UE4  missing
# sub-HBN_CBIC_NDARHT524ET0  missing
# sub-HBN_CBIC_NDARDR595ZE5  missing
# sub-HBN_SI_NDARTR365NCY  missing
# sub-HBN_RU_NDARXY745NXJ  missing
# sub-HBN_RU_NDARPW915RGD  missing
# sub-HBN_RU_NDARCY036NTA  missing
# sub-HBN_CBIC_NDARUH330VE7  missing
# sub-HBN_SI_NDARTX012JHM  missing
# sub-HBN_CUNY_NDARDC504KWE  missing
# sub-HBN_RU_NDARFX710UZA  missing
# sub-HBN_SI_NDARDH328DR9  missing
# sub-HBN_CBIC_NDARZC445DDK  missing
# sub-HBN_RU_NDARVG163VVN  missing
# sub-HBN_RU_NDARYF728BEP  missing
# sub-HBN_RU_NDARJJ413MNH  missing
# sub-HBN_CBIC_NDARFJ330ZUE  missing
# sub-HBN_SI_NDARXB704HFD  missing
# sub-HBN_SI_NDARXF441RHQ  missing
# sub-HBN_CBIC_NDARPH542LMH  missing
# sub-HBN_RU_NDARLP417RC6  missing
# sub-HBN_RU_NDAREN667YTZ  missing
# sub-HBN_CBIC_NDARXC058VZG  missing
# sub-HBN_SI_NDARZF949WTW  missing
# sub-HBN_RU_NDARMU053YEU  missing
# sub-HBN_RU_NDARWE717DEU  missing
# sub-HBN_CBIC_NDARJD111BGM  missing
# sub-HBN_RU_NDARTK682LJE  missing
# sub-HBN_RU_NDARNT225UVD  missing
# sub-HBN_CBIC_NDARAB653ZXP  missing
# sub-HBN_CBIC_NDARAR358RHK  missing
# sub-HBN_CBIC_NDARRC355BM6  missing
# sub-HBN_RU_NDARGA499CKF  missing
# sub-HBN_CUNY_NDARUY024RVP  missing
# sub-HBN_RU_NDARLV252DY2  missing
# sub-HBN_CBIC_NDARRC295CHW  missing
# sub-HBN_CBIC_NDARUX408KJ1  missing
# sub-HBN_CBIC_NDARJV225EYT  missing
# sub-HBN_CUNY_NDARFN031NAN  missing
# sub-HBN_RU_NDARVT454LAE  missing
# sub-HBN_SI_NDARNJ894VH2  missing
# sub-HBN_CBIC_NDARCH838TY6  missing
# sub-HBN_RU_NDARHK526BY1  missing
# sub-HBN_CBIC_NDARMZ936WYB  missing
# sub-HBN_CBIC_NDARGZ301KFG  missing
# sub-HBN_CUNY_NDARYZ761TA3  missing
# sub-HBN_CBIC_NDARLE676JZN  missing
# sub-HBN_RU_NDARRP008LJ6  missing
# sub-HBN_RU_NDARAB055BPR  missing
# sub-HBN_RU_NDARHG152GZC  missing
# sub-HBN_CBIC_NDARBD992CH7  missing
# sub-HBN_CUNY_NDARKC791WL9  missing
# sub-HBN_CBIC_NDARTJ862ENU  missing
# sub-HBN_CBIC_NDARYM586MYN  missing
# sub-HBN_RU_NDARGT267UZR  missing
# sub-HBN_CUNY_NDARFX020XPM  missing
# sub-HBN_CBIC_NDARAP912JK3  missing
# sub-HBN_CBIC_NDARWU018VDB  missing
# sub-HBN_CBIC_NDARFP813TL5  missing
# sub-HBN_CBIC_NDARHW575ZJ5  missing
# sub-HBN_CBIC_NDARWK626PFY  missing
# sub-HBN_CBIC_NDARHW873BP4  missing
# sub-HBN_RU_NDARWR732NZE  missing
# sub-HBN_RU_NDARJP304NK1  missing
# sub-HBN_CBIC_NDARVM774PA5  missing
# sub-HBN_RU_NDARNH200DA6  missing
# sub-HBN_RU_NDARUF850XKH  missing
# sub-HBN_RU_NDARAV820UEP  missing
# sub-HBN_CBIC_NDARGA563XVW  missing
# sub-HBN_CBIC_NDARFN790WHU  missing
# sub-HBN_SI_NDARYB563VRT  missing
# sub-HBN_CBIC_NDARXU975RAJ  missing
# sub-HBN_RU_NDARUX340FYC  missing
# sub-HBN_CBIC_NDARMX591FJ6  missing
# sub-HBN_CBIC_NDARUP067TM8  missing
# sub-HBN_CBIC_NDARXN246RND  missing
# sub-HBN_SI_NDARKF615JNZ  missing
# sub-HBN_RU_NDARDP725ZVY  missing
# sub-HBN_CUNY_NDARDN446FJG  missing
# sub-HBN_CUNY_NDARGM902BME  missing
# sub-HBN_RU_NDARFD822TY5  missing
# sub-HBN_CBIC_NDARXK986EK6  missing
# sub-HBN_CBIC_NDARLF484WJL  missing
# sub-HBN_CUNY_NDARXW976KCR  missing
# sub-HBN_SI_NDARJZ549HU8  missing
# sub-HBN_CBIC_NDARCU744XWL  missing
# sub-HBN_CBIC_NDARMV822KWR  missing
# sub-HBN_RU_NDARBE091BGD  missing
# sub-HBN_CBIC_NDARVM741LKK  missing
# sub-HBN_CBIC_NDARFR103CUN  missing
# sub-HBN_CBIC_NDARDE319VD1  missing
# sub-HBN_RU_NDARHM475DC5  missing
# sub-HBN_RU_NDARYA379LKT  missing
# sub-HBN_SI_NDARVT231LJG  missing
# sub-HBN_CBIC_NDARBZ444ZHK  missing
# sub-HBN_RU_NDARCF247TDJ  missing
# sub-HBN_CUNY_NDARZU615HUG  missing
# sub-HBN_RU_NDARHY177LY9  missing
# sub-HBN_CUNY_NDARJV512CXQ  missing
# sub-HBN_CBIC_NDARJT615WM7  missing
# sub-HBN_CUNY_NDARKD296VKD  missing
# sub-HBN_CUNY_NDARER054VLK  missing
# sub-HBN_RU_NDARBT607PZL  missing
# sub-HBN_CUNY_NDARZR022UDZ  missing
# sub-HBN_RU_NDARTN158LRF  missing
# sub-HBN_RU_NDARLJ654TZ0  missing
# sub-HBN_CBIC_NDARCU057BFP  missing
# sub-HBN_CBIC_NDARHK506HLW  missing
# sub-HBN_CBIC_NDARPE424GZZ  missing
# sub-HBN_SI_NDARPP337KUQ  missing
# sub-HBN_CBIC_NDAREM155HGQ  missing
# sub-HBN_CBIC_NDARJC294YNX  missing
# sub-HBN_CUNY_NDARJF399BC6  missing
# sub-HBN_RU_NDAREM731BYM  missing
# sub-HBN_RU_NDARYK942YHY  missing
# sub-HBN_CBIC_NDARYZ946EUH  missing
# sub-HBN_RU_NDARNR709MMQ  missing
# sub-HBN_CUNY_NDARXJ349THV  missing
# sub-HBN_CBIC_NDARZB517KTU  missing
# sub-HBN_RU_NDARZF625MH8  missing
# sub-HBN_CBIC_NDARHP395DGY  missing
# sub-HBN_CBIC_NDARMN802MG9  missing
# sub-HBN_CUNY_NDARKJ238NTJ  missing
# sub-HBN_RU_NDARJW989EM6  missing
# sub-HBN_RU_NDARBA680RFY  missing
# sub-HBN_RU_NDARNE758RD6  missing
# sub-HBN_RU_NDARUJ779NM0  missing
# sub-HBN_CBIC_NDARCG947ZC0  missing
# sub-HBN_RU_NDARAX272ZJL  missing
# sub-HBN_SI_NDARRU600XWW  missing
# sub-HBN_SI_NDARMN450PEH  missing
# sub-HBN_RU_NDARDE681UEX  missing
# sub-HBN_CUNY_NDARTK897DPP  missing
# sub-HBN_CUNY_NDARVU390GVK  missing
# sub-HBN_CBIC_NDARFJ000DCY  missing
# sub-HBN_CBIC_NDARNX843CD9  missing
# sub-HBN_CBIC_NDARCM268ULX  missing
# sub-HBN_RU_NDARXB286YBR  missing
# sub-HBN_CBIC_NDARWZ346RV4  missing
# sub-HBN_CUNY_NDARUB690GWK  missing
# sub-HBN_CBIC_NDARKU649DB7  missing
# sub-HBN_RU_NDARRM320RHN  missing
# sub-HBN_CBIC_NDARXX899HTP  missing
# sub-HBN_CBIC_NDARJL422NDV  missing
# sub-HBN_CBIC_NDARBE942GVN  missing
# sub-HBN_CBIC_NDARTH173DWQ  missing
# sub-HBN_CUNY_NDARGL586HN9  missing
# sub-HBN_CBIC_NDARMU967FL9  missing
# sub-HBN_CUNY_NDARHK956CJJ  missing
# sub-HBN_SI_NDARHX877BLQ  missing
# sub-HBN_CBIC_NDARBT436PMT  missing
# sub-HBN_RU_NDARZJ460RWZ  missing
# sub-HBN_CBIC_NDARXC921EL3  missing
# sub-HBN_CBIC_NDARLH043YDK  missing
# sub-HBN_CBIC_NDARRA719XBF  missing
# sub-HBN_RU_NDARFV685ZT2  missing
# sub-HBN_RU_NDARNM147CG2  missing
# sub-HBN_CBIC_NDARHR763RB4  missing
# sub-HBN_CBIC_NDARTT287KFN  missing
# sub-HBN_RU_NDARKX701BJ4  missing
# sub-HBN_CUNY_NDARTN793TBY  missing
# sub-HBN_CBIC_NDARKC220LZG  missing
# sub-HBN_CBIC_NDARBX076DCX  missing
# sub-HBN_RU_NDARWF422UK3  missing
# sub-HBN_RU_NDARJL303FKR  missing
# sub-HBN_CUNY_NDARRU711AP5  missing
# sub-HBN_RU_NDARGF367KVL  missing
# sub-HBN_RU_NDARUF828TV2  missing
# sub-HBN_CUNY_NDARPU887XGA  missing
# sub-HBN_CBIC_NDARFJ651RMJ  missing
# sub-HBN_SI_NDARRZ199KNG  missing
# sub-HBN_CBIC_NDARGH425GB9  missing
# sub-HBN_CBIC_NDARVM586CBM  missing
# sub-HBN_CBIC_NDARKG990TNT  missing
# sub-HBN_CBIC_NDARMY873XG5  missing
# sub-HBN_RU_NDARZV983XK9  missing
# sub-HBN_RU_NDARRR622MYT  missing
# sub-HBN_CUNY_NDARZR881BWX  missing
# sub-HBN_RU_NDAREC486ZPV  missing
# sub-HBN_CBIC_NDARHG188YE9  missing
# sub-HBN_SI_NDARGH407KVG  missing
# sub-HBN_CBIC_NDARPT497YFZ  missing
# sub-HBN_RU_NDARPV145KGL  missing
# sub-HBN_RU_NDARJH707GJM  missing
# sub-HBN_CUNY_NDARRA908XA2  missing
# sub-HBN_CBIC_NDARWM835BR8  missing
# sub-HBN_RU_NDARXB023AMW  missing
# sub-HBN_RU_NDARKD064EVC  missing
# sub-HBN_CBIC_NDARBA381JGH  missing
# sub-HBN_CUNY_NDARMH095VH7  missing
# sub-HBN_RU_NDARJX505XD6  missing
# sub-HBN_SI_NDARZE542ZVH  missing
# sub-HBN_CUNY_NDARYL835DRL  missing
# sub-HBN_CBIC_NDARYA030ZG7  missing
# sub-HBN_SI_NDARED632KNG  missing
# sub-HBN_CBIC_NDARTH930FNK  missing
# sub-HBN_RU_NDARPJ001BVE  missing
# sub-HBN_RU_NDARMC759CX3  missing
# sub-HBN_CBIC_NDARLV155RW0  missing
# sub-HBN_CBIC_NDARUK658FMU  missing
# sub-HBN_CUNY_NDARRE588NRM  missing
# sub-HBN_CUNY_NDARKT721PNV  missing
# sub-HBN_RU_NDARVN648NN2  missing
# sub-HBN_CBIC_NDARHC562JGU  missing
# sub-HBN_CBIC_NDARWY514DEX  missing
# sub-HBN_CBIC_NDARTF378MX6  missing
# sub-HBN_CBIC_NDARKZ479FC8  missing
# sub-HBN_CBIC_NDARJA959GNZ  missing
# sub-HBN_CBIC_NDARTU319KKP  missing
# sub-HBN_CBIC_NDARHZ413DZL  missing
# sub-HBN_RU_NDARDM118LR6  missing
# sub-HBN_CBIC_NDARYD666FL0  missing
# sub-HBN_SI_NDARYL438DCK  missing
# sub-HBN_CUNY_NDAREC917PX7  missing
# sub-HBN_SI_NDARHL238VL2  missing
# sub-HBN_SI_NDARDT800YVF  missing
# sub-HBN_RU_NDARZH451LRZ  missing
# sub-HBN_CBIC_NDARYH603BDN  missing
# sub-HBN_SI_NDARYX530MZU  missing
# sub-HBN_CBIC_NDARJH773JTJ  missing
# sub-HBN_RU_NDARCM135DVC  missing
# sub-HBN_CBIC_NDARNM722GA4  missing
# sub-HBN_SI_NDARBN100LCD  missing
# sub-HBN_CBIC_NDARZP599GRG  missing
# sub-HBN_RU_NDARYY664KHF  missing
# sub-HBN_CUNY_NDARJM880XGY  missing
# sub-HBN_CBIC_NDARNN745ZEK  missing
# sub-HBN_CBIC_NDARRY803NR6  missing
# sub-HBN_RU_NDARAA306NT2  missing
# sub-HBN_CBIC_NDARNL587LVL  missing
# sub-HBN_CBIC_NDARJF156KMU  missing
# sub-HBN_CUNY_NDARNH766CU7  missing
# sub-HBN_CUNY_NDARAW427GWK  missing
# sub-HBN_RU_NDARGK449LLK  missing
# sub-HBN_CUNY_NDARKG294DZN  missing
# sub-HBN_CBIC_NDARUW206XUG  missing
# sub-HBN_CUNY_NDARRK431RX8  missing
# sub-HBN_CUNY_NDARDJ204EPU  missing
# sub-HBN_RU_NDARGA048BD8  missing
# sub-HBN_RU_NDARAG340ERT  missing
# sub-HBN_RU_NDARRB942UWU  missing
# sub-HBN_CBIC_NDARLY867ZD4  missing
# sub-HBN_RU_NDARTG937LDA  missing
# sub-HBN_CBIC_NDAREJ327AH7  missing
# sub-HBN_CBIC_NDARRU560UUG  missing
# sub-HBN_RU_NDARKN509RP9  missing
# sub-HBN_CBIC_NDARAD459XJK  missing
# sub-HBN_CUNY_NDARCA127TK7  missing
# sub-HBN_CBIC_NDARXU376FDN  missing
# sub-HBN_RU_NDARPA570LBF  missing
# sub-HBN_RU_NDARPZ720WKW  missing
# sub-HBN_RU_NDARLJ886BFK  missing
# sub-HBN_RU_NDARCA740UC8  missing
# ...
# sub-HBN_RU_NDARWW003WWW  missing
# sub-HBN_RU_NDARTT194LTU  missing
# sub-HBN_CBIC_NDARVP953BBF  missing
# sub-HBN_CUNY_NDARRV843HGK  missing
# sub-HBN_RU_NDARUX284GGB  missing
# sub-HBN_CBIC_NDARTL878RZ2  missing
# sub-HBN_CBIC_NDARZZ741VJE  missing
# sub-HBN_CBIC_NDARWA542JCG  missing
# sub-HBN_CBIC_NDARXB870BCV  missing
# sub-HBN_CUNY_NDARWV313RH7  missing
# sub-HBN_RU_NDARMR039JV5  missing
# sub-HBN_CBIC_NDARWV487HE0  missing
# sub-HBN_RU_NDARML406ZB8  missing
# sub-HBN_RU_NDARYG665JUD  missing
# sub-HBN_RU_NDARTN487KDK  missing
# sub-HBN_CBIC_NDARKF704MKL  missing
# sub-HBN_RU_NDARCW963FP9  missing
# sub-HBN_RU_NDARAC462DZH  missing
# sub-HBN_RU_NDARRY280KNW  missing
# sub-HBN_RU_NDARUD776KFT  missing
# sub-HBN_CBIC_NDARFT787HJW  missing
# sub-HBN_RU_NDARFW038ZNE  missing
# sub-HBN_CBIC_NDARBK032VNE  missing
# sub-HBN_CBIC_NDARHU910KZC  missing
# sub-HBN_RU_NDARMW178UDD  missing
# sub-HBN_RU_NDARHU391FD7  missing
# sub-HBN_CBIC_NDARGE994BMX  missing
# sub-HBN_CBIC_NDARCK815WZR  missing
# sub-HBN_CUNY_NDARTH459BLU  missing
# sub-HBN_CUNY_NDARGL619EVM  missing
# sub-HBN_CUNY_NDARZF679JLV  missing
# sub-HBN_CUNY_NDARJV697PMQ  missing
# sub-HBN_RU_NDARBJ159HXB  missing
# sub-HBN_RU_NDARBH133TK6  missing
# sub-HBN_RU_NDARYA503XVQ  missing
# sub-HBN_CBIC_NDARYK042VMG  missing
# sub-HBN_SI_NDARMJ699RJN  missing
# sub-HBN_CUNY_NDARAM383UYD  missing
# sub-HBN_SI_NDARBU112XZE  missing
# sub-HBN_CBIC_NDARHP344PRU  missing
# sub-HBN_CBIC_NDARRW475MPT  missing
# sub-HBN_CBIC_NDARPL194XDX  missing
# sub-HBN_RU_NDARZW363UGM  missing
# sub-HBN_RU_NDARRH344TL7  missing
# sub-HBN_CBIC_NDARCN497LVY  missing
# sub-HBN_CUNY_NDARHY787LAL  missing
# sub-HBN_CUNY_NDARTA364TAU  missing
# sub-HBN_SI_NDARVG971CHH  missing
# sub-HBN_CBIC_NDARBK106KRH  missing
# sub-HBN_CUNY_NDARUT136EUY  missing
# sub-HBN_CBIC_NDARFU786BN4  missing
# sub-HBN_CUNY_NDARHR191HKK  missing
# sub-HBN_RU_NDARBE641DGZ  missing
# sub-HBN_CBIC_NDARNJ633HHX  missing
# sub-HBN_CBIC_NDARFG118DW3  missing
# sub-HBN_RU_NDARHL164JHH  missing
# sub-HBN_RU_NDARLE554GYT  missing
# sub-HBN_CUNY_NDARTG029XTK  missing
# sub-HBN_CBIC_NDARTB661TVR  missing
# sub-HBN_SI_NDARDX770PJK  missing
# sub-HBN_CBIC_NDARCM811CV1  missing
# sub-HBN_RU_NDARTK507RJW  missing
# sub-HBN_RU_NDARCW933FD5  missing
# sub-HBN_CBIC_NDARYT509KUF  missing
# sub-HBN_SI_NDARZH629NVF  missing
# sub-HBN_CBIC_NDARJF479TBL  missing
# sub-HBN_CBIC_NDARME789TD2  missing
# sub-HBN_RU_NDARHG232EWH  missing
# sub-HBN_RU_NDARCN669XPR  missing
# sub-HBN_CBIC_NDAREN999ERM  missing
# sub-HBN_CBIC_NDARWH778CPD  missing
# sub-HBN_CUNY_NDARCE826DYW  missing
# sub-HBN_CBIC_NDARCP642KML  missing
# sub-HBN_CBIC_NDARXM571XCC  missing
# sub-HBN_RU_NDARMH249AWF  missing
# sub-HBN_CUNY_NDARMR744CZ7  missing
# sub-HBN_CBIC_NDARVU464RBF  missing
# sub-HBN_CUNY_NDARNL547DDH  missing
# sub-HBN_CBIC_NDARCA050RZL  missing
# sub-HBN_RU_NDARWN709HA2  missing
# sub-HBN_RU_NDARTW889JN9  missing
# sub-HBN_CBIC_NDARAV474ADJ  missing
# sub-HBN_RU_NDARYW945PJU  missing
# sub-HBN_RU_NDARKK774VP5  missing
# sub-HBN_CBIC_NDARLP507NKW  missing
# sub-HBN_SI_NDARBZ216FW8  missing
# sub-HBN_RU_NDARDC704GKW  missing
# sub-HBN_CBIC_NDARUF230BYM  missing
# sub-HBN_CBIC_NDARWM682YJ0  missing
# sub-HBN_CUNY_NDAREK862TN1  missing
# sub-HBN_CUNY_NDARZV458LDP  missing
# sub-HBN_CBIC_NDARXP873PZZ  missing
# sub-HBN_RU_NDARNT676ZN4  missing
# sub-HBN_CUNY_NDARGL289TB8  missing
# sub-HBN_CBIC_NDAREH333KZD  missing
# sub-HBN_RU_NDARRL660CME  missing
# sub-HBN_RU_NDARMM486AJU  missing
# sub-HBN_RU_NDARHM413HVA  missing
# sub-HBN_RU_NDARTF133LLM  missing
# sub-HBN_CBIC_NDARTA246MJP  missing
# sub-HBN_CBIC_NDARUK931MGT  missing
# sub-HBN_CBIC_NDARAC331VEH  missing
# sub-HBN_CBIC_NDARAW216PM7  missing
# sub-HBN_CBIC_NDARNT151UN1  missing
# sub-HBN_CBIC_NDARNX672HNV  missing
# sub-HBN_SI_NDARMM905VYR  missing
# sub-HBN_CBIC_NDARKT312RUD  missing
# sub-HBN_RU_NDARVR116KG5  missing
# sub-HBN_CBIC_NDARUX534HZQ  missing
# sub-HBN_CBIC_NDARCP452ZVH  missing
# sub-HBN_CBIC_NDARJV062AM0  missing
# sub-HBN_RU_NDARBU730PN8  missing
# sub-HBN_SI_NDARKC452YVR  missing
# sub-HBN_RU_NDARUP249AMD  missing
# sub-HBN_RU_NDARTT667RKQ  missing
# sub-HBN_CBIC_NDARGC471KD1  missing
# sub-HBN_SI_NDARTK657DV6  missing
# sub-HBN_RU_NDARRX819BZ0  missing
# sub-HBN_RU_NDARTP270UAV  missing
# sub-HBN_CUNY_NDARNY393MAC  missing
# sub-HBN_CBIC_NDARZR180BM6  missing
# sub-HBN_RU_NDARUR153ZWB  missing
# sub-HBN_CUNY_NDARMW623RTE  missing
# sub-HBN_CBIC_NDARYM277DEA  missing
# sub-HBN_CBIC_NDARYX572VEW  missing
# sub-HBN_CBIC_NDARKR155ME9  missing
# sub-HBN_RU_NDARVC305AC6  missing
# sub-HBN_CBIC_NDAREK255DEE  missing
# sub-HBN_SI_NDAREK544ENR  missing
# sub-HBN_SI_NDARAT299YRR  missing
# sub-HBN_RU_NDARPW313LAJ  missing
# sub-HBN_RU_NDARCV628UUW  missing
# sub-HBN_CBIC_NDARNC489BX5  missing
# sub-HBN_RU_NDARJY645CRH  missing
# sub-HBN_RU_NDARWX338NDL  missing
# sub-HBN_CUNY_NDARBF911MLX  missing
# sub-HBN_RU_NDARCA153NKE  missing
# sub-HBN_SI_NDARAV945MCQ  missing
# sub-HBN_RU_NDARUE603CHQ  missing
# sub-HBN_CBIC_NDARHG906MEZ  missing
# sub-HBN_CBIC_NDARRY006EMB  missing
# sub-HBN_CBIC_NDARHB452LTW  missing
# sub-HBN_RU_NDARGK736HF4  missing
# sub-HBN_CBIC_NDARRR595LRJ  missing
# sub-HBN_CBIC_NDARAW298ZA9  missing
# sub-HBN_SI_NDARTA808DEQ  missing
# sub-HBN_RU_NDARBE287EFC  missing
# sub-HBN_CBIC_NDARYF699FW0  missing
# sub-HBN_RU_NDARPT910NEE  missing
# sub-HBN_RU_NDAREB093GH6  missing
# sub-HBN_RU_NDARXN764AC7  missing
# sub-HBN_CUNY_NDARAW558WUT  missing
# sub-HBN_SI_NDARCW419GBD  missing
# sub-HBN_RU_NDARLY687YDQ  missing
# sub-HBN_RU_NDARCH868WVX  missing
# sub-HBN_CUNY_NDARWK625CUV  missing
# sub-HBN_RU_NDARWC801CB5  missing
# sub-HBN_CUNY_NDARTF081PRL  missing
# sub-HBN_CUNY_NDARNN042YCH  missing
# sub-HBN_CBIC_NDARTE115TAE  missing
# sub-HBN_CBIC_NDARLZ745EUN  missing
# sub-HBN_CBIC_NDARUC591FWN  missing
# sub-HBN_CUNY_NDARYW170CAA  missing
# sub-HBN_RU_NDARDE294HNX  missing
# sub-HBN_CUNY_NDARNL971TL5  missing
# sub-HBN_RU_NDARLL720BGU  missing
# sub-HBN_CUNY_NDARMY291ZPH  missing
# sub-HBN_CUNY_NDARMH127CEW  missing
# sub-HBN_RU_NDARHX418ZGJ  missing
# sub-HBN_CBIC_NDARLT365LHK  missing
# sub-HBN_RU_NDARLV387GP4  missing
# sub-HBN_RU_NDARDT181RP4  missing
# sub-HBN_CUNY_NDARAL897CYV  missing
# sub-HBN_CBIC_NDARPF682GDC  missing
# sub-HBN_RU_NDARUN300FG1  missing
# sub-HBN_SI_NDARUY876VL1  missing
# sub-HBN_CUNY_NDARBK739HXR  missing
# sub-HBN_RU_NDARJK154PF5  missing
# sub-HBN_CUNY_NDARPA414ARE  missing
# sub-HBN_CBIC_NDARYG130LBT  missing
# sub-HBN_RU_NDARDJ970ELG  missing
# sub-HBN_CBIC_NDARLE282UHJ  missing
# sub-HBN_CBIC_NDARZK745JGG  missing
# sub-HBN_CUNY_NDARPL108LAV  missing
# sub-HBN_CBIC_NDARVB012UWL  missing
# sub-HBN_RU_NDARAP176AD1  missing
# sub-HBN_CBIC_NDAREK130FBX  missing
# sub-HBN_CBIC_NDARXN893UEZ  missing
# sub-HBN_CUNY_NDARCY049DAF  missing
# sub-HBN_SI_NDARCJ007GF8  missing
# sub-HBN_CBIC_NDARPB957JXE  missing
# sub-HBN_CUNY_NDARVL789JCG  missing
# sub-HBN_CBIC_NDARAR238RZ8  missing
# sub-HBN_CBIC_NDARCR582GKJ  missing
# sub-HBN_CUNY_NDARRG346DNL  missing
# sub-HBN_CUNY_NDARNP962TJK  missing
# sub-HBN_CBIC_NDARKN139APF  missing
# sub-HBN_RU_NDARRD326KB9  missing
# sub-HBN_CUNY_NDARRM938ZXD  missing
# sub-HBN_CUNY_NDARYH501UH3  missing
# sub-HBN_CBIC_NDARZK601NG9  missing
# sub-HBN_RU_NDAREH074NG8  missing
# sub-HBN_RU_NDAREW074ZM2  missing
# sub-HBN_CUNY_NDARHR448DEV  missing
# sub-HBN_CBIC_NDARYF272EDC  missing
# sub-HBN_CBIC_NDARGW450YUX  missing
# sub-HBN_CBIC_NDARWN739ED2  missing
# sub-HBN_RU_NDARNP812WAQ  missing
# sub-HBN_RU_NDARUZ206DRV  missing
# sub-HBN_RU_NDARXD345GBN  missing
# sub-HBN_CBIC_NDARJF517HC8  missing
# sub-HBN_CBIC_NDARYN174NPH  missing
# sub-HBN_RU_NDARUY379PT5  missing
# sub-HBN_CUNY_NDARUN771DPA  missing
# sub-HBN_CUNY_NDARLB291FBV  missing
# sub-HBN_CBIC_NDARUZ200NRJ  missing
# sub-HBN_CBIC_NDARDB720VEA  missing
# sub-HBN_RU_NDAREG561ML5  missing
# sub-HBN_CBIC_NDARFR696PLG  missing
# sub-HBN_CBIC_NDARMV605LGH  missing
# sub-HBN_CBIC_NDARHC426PAW  missing
# sub-HBN_SI_NDARHT218GFA  missing
# sub-HBN_RU_NDARNZ043VH0  missing
# sub-HBN_CBIC_NDARKZ198TAA  missing
# sub-HBN_RU_NDARCY178KJP  missing
# sub-HBN_RU_NDARHN749RW4  missing
# sub-HBN_RU_NDARJG494YDY  missing
# sub-HBN_RU_NDARWG831JJ8  missing
# sub-HBN_CUNY_NDARAV082JHA  missing
# sub-HBN_RU_NDARWA102TY7  missing
# sub-HBN_CBIC_NDARYP863PZ4  missing
# sub-HBN_CUNY_NDARLJ933JPP  missing
# sub-HBN_CBIC_NDARFU395UBW  missing
# sub-HBN_CBIC_NDARAX277ATU  missing
# sub-HBN_CBIC_NDARTU841ZAE  missing
# sub-HBN_CUNY_NDARMN151FLL  missing
# sub-HBN_CUNY_NDARZN501NFF  missing
# sub-HBN_RU_NDARPM105MKA  missing
# sub-HBN_RU_NDARMJ334ZK3  missing
# sub-HBN_CBIC_NDARCB305AFY  missing
# sub-HBN_CBIC_NDARXW330ZJT  missing
# sub-HBN_CUNY_NDARXG961UAB  missing
# sub-HBN_CBIC_NDARVF544YP6  missing
# sub-HBN_RU_NDARYZ770NA1  missing
# sub-HBN_SI_NDARWB685NUG  missing
# sub-HBN_CBIC_NDARFZ143BUQ  missing
# sub-HBN_CBIC_NDARVC140PKY  missing
# sub-HBN_RU_NDARER379GTP  missing
# sub-HBN_RU_NDARGV948BFZ  missing
# sub-HBN_CBIC_NDARNV375KEK  missing
# sub-HBN_RU_NDARDU986RBM  missing
# sub-HBN_CBIC_NDARUT233WU9  missing
# sub-HBN_CBIC_NDARET671FTC  missing
# sub-HBN_RU_NDARGU100JH4  missing
# sub-HBN_CUNY_NDAREW531JV9  missing
# sub-HBN_CUNY_NDARTH990UEC  missing
# sub-HBN_CBIC_NDARZX384XVQ  missing
# sub-HBN_SI_NDARXY337ZH9  missing
# sub-HBN_CBIC_NDAREW326RXX  missing
# sub-HBN_CBIC_NDARAX075WL9  missing
# sub-HBN_RU_NDARRA933RLX  missing
# sub-HBN_CBIC_NDARGC407NV7  missing
# sub-HBN_CUNY_NDARZA151EU8  missing
# sub-HBN_CUNY_NDARGB101GUF  missing
# sub-HBN_CBIC_NDARAD256AHU  missing
# sub-HBN_SI_NDARHM304AXP  missing
# sub-HBN_CBIC_NDARHD841JAE  missing
# sub-HBN_CBIC_NDARHC825ZFZ  missing
# sub-HBN_CUNY_NDARPM172XGD  missing
# sub-HBN_CUNY_NDARTP149FG8  missing
# sub-HBN_RU_NDARNZ792HBN  missing
# sub-HBN_RU_NDARRJ989YPA  missing
# sub-HBN_CBIC_NDARVF786FUU  missing
# sub-HBN_CBIC_NDARML681XZJ  missing
# sub-HBN_CBIC_NDARGA589KWK  missing
# sub-HBN_CBIC_NDARDL377ZT7  missing
# sub-HBN_CBIC_NDARCW932EU6  missing
# sub-HBN_CBIC_NDARLA048NYE  missing
# sub-HBN_CBIC_NDARWP732GD1  missing
# sub-HBN_CBIC_NDARJU787GF5  missing
# sub-HBN_CBIC_NDARHE199NGL  missing
# sub-HBN_CUNY_NDARLV311HWL  missing
# sub-HBN_CBIC_NDARJH159UD4  missing
# sub-HBN_SI_NDARKW999WZD  missing
# sub-HBN_SI_NDARMH763YZD  missing
# sub-HBN_RU_NDARBX121UM9  missing
# sub-HBN_RU_NDARET550NXC  missing
# sub-HBN_CBIC_NDARPC222WN6  missing
# sub-HBN_CBIC_NDARYN152YMW  missing
# sub-HBN_CBIC_NDARMH364EMW  missing
# sub-HBN_SI_NDARVG148WHV  missing
# sub-HBN_CBIC_NDARFA780CUG  missing
# sub-HBN_SI_NDARCB959FY4  missing
# sub-HBN_SI_NDARWX380JJK  missing
# sub-HBN_CUNY_NDARCJ667UPL  missing
# sub-HBN_RU_NDARCZ915NC1  missing
# sub-HBN_RU_NDARCV944JA6  missing
# sub-HBN_RU_NDARWP815VUP  missing
# sub-HBN_RU_NDARMR134HUY  missing
# sub-HBN_CBIC_NDARKP458TM1  missing
# sub-HBN_CBIC_NDARUE991BE0  missing
# sub-HBN_CUNY_NDARPE497UEY  missing
# sub-HBN_CUNY_NDARKK633KD2  missing
# sub-HBN_CBIC_NDARKN175HWB  missing
# sub-HBN_CBIC_NDARFV725DEQ  missing
# sub-HBN_CBIC_NDAREN352YZQ  missing
# sub-HBN_CUNY_NDARYK713TGJ  missing
# sub-HBN_RU_NDARGZ361JJ9  missing
# sub-HBN_CBIC_NDARFA233CUK  missing
# sub-HBN_CUNY_NDARMA657LLB  missing
# sub-HBN_CUNY_NDARCB492BAD  missing
# sub-HBN_SI_NDARGM498YFL  missing
# sub-HBN_SI_NDARWV677EFC  missing
# sub-HBN_CBIC_NDARTF776EYR  missing
# sub-HBN_CBIC_NDARKD590VF4  missing
# sub-HBN_CUNY_NDARUD345RW8  missing
# sub-HBN_CBIC_NDARAN525BVK  missing
# sub-HBN_CBIC_NDARCD687JUZ  missing
# sub-HBN_RU_NDARGH790CEF  missing
# sub-HBN_RU_NDARED628HMQ  missing
# sub-HBN_SI_NDARPF118ABV  missing
# sub-HBN_SI_NDARKH741PL8  missing
# sub-HBN_CUNY_NDARRK617NRL  missing
# sub-HBN_CBIC_NDARAX287BLD  missing
# sub-HBN_CUNY_NDARAR998KMM  missing
# sub-HBN_CBIC_NDARRF525ME3  missing
# sub-HBN_RU_NDARFJ372JDJ  missing
# sub-HBN_CUNY_NDARRP175MBY  missing
# sub-HBN_CBIC_NDARUL077YNE  missing
# sub-HBN_RU_NDARLA226ADX  missing
# sub-HBN_RU_NDARHV527DNK  missing
# sub-HBN_CBIC_NDARKE254HKM  missing
# sub-HBN_RU_NDARMD575AXD  missing
# sub-HBN_RU_NDARXG571WPL  missing
# sub-HBN_RU_NDARBJ482HJL  missing
# sub-HBN_CBIC_NDARDE597GKQ  missing
# sub-HBN_RU_NDARAM848GTE  missing
# sub-HBN_CUNY_NDARPE460HAN  missing
# sub-HBN_RU_NDARGW404GJL  missing
# sub-HBN_SI_NDAREC182WW2  missing
# sub-HBN_CBIC_NDARLU939YX4  missing
# sub-HBN_SI_NDAREY962BM7  missing
# sub-HBN_RU_NDARZE389XF0  missing
# sub-HBN_RU_NDARKM301DY0  missing
# sub-HBN_CBIC_NDARNC287MK5  missing
# sub-HBN_RU_NDARNZ917TDK  missing
# sub-HBN_CBIC_NDARBF293YRB  missing
# sub-HBN_CBIC_NDARXN641PWT  missing
# sub-HBN_RU_NDARDZ440NGK  missing
# sub-HBN_CBIC_NDARMZ477MNH  missing
# sub-HBN_CUNY_NDARNT858ZU2  missing
# sub-HBN_RU_NDARXJ973GFA  missing
# sub-HBN_RU_NDARXL023NG9  missing
# sub-HBN_RU_NDARVC310XV2  missing
# sub-HBN_CBIC_NDARJG581CCK  missing
# sub-HBN_CUNY_NDARLZ995KLB  missing
# sub-HBN_CBIC_NDARKX116PGU  missing
# sub-HBN_CBIC_NDARVX547MA0  missing
# sub-HBN_CBIC_NDARKX371CJY  missing
# sub-HBN_CUNY_NDARNR630AK6  missing
# sub-HBN_RU_NDARGC124PAW  missing
# sub-HBN_SI_NDARGA967MGC  missing
# sub-HBN_RU_NDARLU529MP7  missing
# sub-HBN_CUNY_NDARAM357BUA  missing
# sub-HBN_CUNY_NDARCG099GTV  missing
# sub-HBN_RU_NDARMN695VFH  missing
# sub-HBN_RU_NDARME736MN8  missing
# sub-HBN_CBIC_NDARHZ852XY0  missing
# sub-HBN_CBIC_NDARPL406KX4  missing
# sub-HBN_CUNY_NDARJZ919LPL  missing
# sub-HBN_RU_NDARBJ375VP4  missing
# sub-HBN_RU_NDARHF545HFW  missing
# sub-HBN_SI_NDARHP656DLC  missing
# sub-HBN_SI_NDARWV470ATB  missing
# sub-HBN_RU_NDAREG013BLG  missing
# sub-HBN_RU_NDARJA157YB3  missing
# sub-HBN_CBIC_NDARUC994BLZ  missing
# sub-HBN_RU_NDARHW158PPR  missing
# sub-HBN_CUNY_NDARTL107DMD  missing
# sub-HBN_SI_NDARXK164TNN  missing
# sub-HBN_CBIC_NDARPM528TBR  missing
# sub-HBN_RU_NDARCC824FCL  missing
# sub-HBN_SI_NDARUA421HT8  missing
# sub-HBN_CBIC_NDARYV538EBP  missing
# sub-HBN_CUNY_NDARHD079LCL  missing
# sub-HBN_RU_NDARRU729XRU  missing
# sub-HBN_CBIC_NDARGY542TJ5  missing
# sub-HBN_CBIC_NDARZA511FYF  missing
# sub-HBN_RU_NDAREX065KJU  missing
# sub-HBN_SI_NDAREM141CKP  missing
# sub-HBN_CUNY_NDARFJ423LW9  missing
# sub-HBN_CBIC_NDARWV403LV8  missing
# sub-HBN_CUNY_NDARBH275EXT  missing
# sub-HBN_CBIC_NDARTJ963NC8  missing
# sub-HBN_CBIC_NDARGZ553TMQ  missing
# sub-HBN_SI_NDARHJ946UPH  missing
# sub-HBN_CBIC_NDARGV455JV1  missing
# sub-HBN_CUNY_NDARNE098NPR  missing
# sub-HBN_RU_NDARFE299MWU  missing
# sub-HBN_CBIC_NDARGY959RN8  missing
# sub-HBN_CBIC_NDARRN626DC4  missing
# sub-HBN_RU_NDARPK300HMV  missing
# sub-HBN_CUNY_NDARWV731NCC  missing
# sub-HBN_CBIC_NDARFW253GZM  missing
# sub-HBN_CBIC_NDAREK549XUQ  missing
# sub-HBN_CBIC_NDARAB977GFB  missing
# sub-HBN_CBIC_NDARLJ280UCN  missing
# sub-HBN_CUNY_NDARGN205MUG  missing
# sub-HBN_RU_NDARRP163YRC  missing
# sub-HBN_CBIC_NDARLB162XP2  missing
# sub-HBN_RU_NDARGD507TDZ  missing
# sub-HBN_RU_NDARUU801VFA  missing
# sub-HBN_CBIC_NDARCG785NND  missing
# sub-HBN_RU_NDARAR305LXG  missing
# sub-HBN_RU_NDARLB547HJD  missing
# sub-HBN_CBIC_NDARGC822DBX  missing
# sub-HBN_SI_NDARVB607WW4  missing
# sub-HBN_CBIC_NDARDL471LWJ  missing
# sub-HBN_CBIC_NDARKZ312XR1  missing
# sub-HBN_CUNY_NDARGZ888HJN  missing
# sub-HBN_CBIC_NDARDT889RT9  missing
# sub-HBN_RU_NDARPK223WVZ  missing
# sub-HBN_CBIC_NDARBX830ZD4  missing
# sub-HBN_RU_NDARRY714GEY  missing
# sub-HBN_RU_NDARUL694GYN  missing
# sub-HBN_RU_NDARBJ674TVU  missing
# sub-HBN_RU_NDARZR529EJ1  missing
# sub-HBN_RU_NDARBH228RDW  missing
# sub-HBN_CBIC_NDARTW567YUQ  missing
# sub-HBN_RU_NDARZZ740MLM  missing
# sub-HBN_RU_NDARGA346NA7  missing
# sub-HBN_CBIC_NDARAH129BMC  missing
# sub-HBN_RU_NDARXF890FLA  missing
# sub-HBN_CBIC_NDARGM196JMM  missing
# sub-HBN_CUNY_NDAREW557WZM  missing
# sub-HBN_CBIC_NDARPD855ARC  missing
# sub-HBN_CBIC_NDARPV915ZPE  missing
# sub-HBN_CBIC_NDARTV107XD4  missing
# sub-HBN_RU_NDARWV794VM2  missing
# sub-HBN_CBIC_NDARCG808HDJ  missing
# sub-HBN_SI_NDARLP181HLA  missing
# sub-HBN_SI_NDARCA186WGH  missing
# sub-HBN_RU_NDARNK055HVH  missing
# sub-HBN_CBIC_NDARKA170RFD  missing
# sub-HBN_CBIC_NDARWM560DXH  missing
# sub-HBN_CUNY_NDARNN761ZPA  missing
# sub-HBN_CBIC_NDARPK337CLE  missing
# sub-HBN_RU_NDARFA165XBV  missing
# sub-HBN_CUNY_NDARWK212ZPX  missing
# sub-HBN_CBIC_NDARLR924YAV  missing
# sub-HBN_SI_NDARZW013RUH  missing
# sub-HBN_CUNY_NDARWU079DJZ  missing
# sub-HBN_SI_NDARRP592GHK  missing
# sub-HBN_CUNY_NDARCF777CT1  missing
# sub-HBN_CBIC_NDARLL846UYQ  missing
# sub-HBN_CBIC_NDARKN633WZA  missing
# sub-HBN_CUNY_NDARWY550FH5  missing
# sub-HBN_CBIC_NDARAB348EWR  missing
# sub-HBN_RU_NDARME100GK1  missing
# sub-HBN_CUNY_NDARKK117YX5  missing
# sub-HBN_CBIC_NDARHR690ZAM  missing
# sub-HBN_RU_NDARLB671TLU  missing
# sub-HBN_RU_NDARYT155NHX  missing
# sub-HBN_CBIC_NDARLJ228ZF8  missing
# sub-HBN_RU_NDARHR099EWX  missing
# sub-HBN_SI_NDARXN047RUT  missing
# sub-HBN_CBIC_NDARVZ086GL6  missing
# sub-HBN_CBIC_NDARBD328NUQ  missing

# %%
X.shape
# Out:
# (2368, 3498706)

# %%
np.mean(y)
# Out:
# 0.5025337837837838

# %%
reps = 5
accuracy = 0.0

for _ in tqdm(range(reps)):
    x_train, x_test, y_train, y_test = train_test_split(
                    X, y, train_size=0.6, random_state=0, stratify=y)
    clf = RandomForestClassifier(n_estimators=1000)
    clf.fit(x_train,y_train)
    accuracy += np.mean(clf.predict(x_test)==y_test)

print('Accuracy is ',accuracy/reps)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [3:25:06<00:00, 2461.40s/it]
# Accuracy is  0.7995780590717301

# %%
clf.feature_importances_
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ### Notes
#
# 1. propensity matching
# 2. run sporf and morf
# 3. see feature importace
