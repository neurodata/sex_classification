# %%
import pandas as  pd
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %% [markdown]
# ### Visualize data (each image size (113, 137, 113))

# %%
slice = 50
demo_filepath_whitematter = '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp2sub-A00008326_T1w.nii'
demo_filepath_graymatter = '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp1sub-A00008326_T1w.nii'

img_whitematter = nb.load(demo_filepath_whitematter).get_fdata()
sliced_img_whitematter = img_whitematter[:,:,slice]

img_graymatter = nb.load(demo_filepath_graymatter).get_fdata()
sliced_img_graymatter = img_graymatter[:,:,slice]

fig, ax = plt.subplots(1,2, figsize=(16,8))
ax[0].imshow(sliced_img_whitematter)
ax[1].imshow(sliced_img_graymatter)

ax[0].set_title('White matter', fontsize=20)
ax[1].set_title('Gray matter', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Gray matter')

# %% [markdown]
# ### Analyze class distribution and age distribution

# %%
df = pd.read_excel('/Users/jayantadey/data_MRI/subjects_age_sex_data_MRI.xlsx')
df.head()
# Out:
#                  ID      Age     Sex Dataset Dataset-ID
# 0  sub-ABIDE1050339  18.0000    MALE   ABIDE      50339
# 1  sub-ABIDE1050701  18.0000    MALE   ABIDE      50701
# 2  sub-ABIDE1050445  18.1383    MALE   ABIDE      50445
# 3  sub-ABIDE1050459  18.1547    MALE   ABIDE      50459
# 4  sub-ABIDE1050341  18.2000  FEMALE   ABIDE      50341

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8), sharey=True)

total_female = len(df[df['Sex']=='FEMALE'])
total_male = len(df[df['Sex']=='MALE'])

df[df['Sex']=='FEMALE'].hist(ax=ax[0])
df[df['Sex']=='MALE'].hist(ax=ax[1])

ax[0].set_title('Female ('+str(total_female)+')', fontsize=20)
ax[1].set_title('Male ('+str(total_male)+')', fontsize=20)

ax[0].set_ylabel('Age', fontsize=20)
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# ### Load data and build (feature, label)

# %%
path = '/Users/jayantadey/data_MRI/'
subjects = os.listdir(path)
X = []
y = []
IDs = set(df['ID'])
for subject in subjects:
    if subject in IDs:
        #print(df[df['ID']==subject]['Sex'])
        sex = int(df[df['ID']==subject]['Sex'].item()=='FEMALE')
        y.append(sex)
        current_file = os.path.join(path, subject)
        tmp = []
        for file in glob.glob(current_file+'/mri/*'):
            tmp.append(nb.load(file).get_fdata().reshape(-1))
        X.append(np.array(tmp).reshape(-1))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[86], line 14
#      12 tmp = []
#      13 for file in glob.glob(current_file+'/mri/*'):
# ---> 14     tmp.append(nb.load(file).get_fdata().reshape(-1))
#      15 X.append(np.array(tmp).reshape(-1))
#
# File ~/miniforge3/envs/env/lib/python3.9/site-packages/nibabel/dataobj_images.py:373, in DataobjImage.get_fdata(self, caching, dtype)
#     369         return self._fdata_cache
#     370 # Always return requested data type
#     371 # For array proxies, will attempt to confine data array to dtype
#     372 # during scaling
# --> 373 data = np.asanyarray(self._dataobj, dtype=dtype)
#     374 if caching == 'fill':
#     375     self._fdata_cache = data
#
# File ~/miniforge3/envs/env/lib/python3.9/site-packages/nibabel/arrayproxy.py:457, in ArrayProxy.__array__(self, dtype)
#     436 def __array__(self, dtype=None):
#     437     """Read data from file and apply scaling, casting to ``dtype``
#     438
#     439     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)
#     455         Scaled image data with type `dtype`.
#     456     """
# --> 457     arr = self._get_scaled(dtype=dtype, slicer=())
#     458     if dtype is not None:
#     459         arr = arr.astype(dtype, copy=False)
#
# File ~/miniforge3/envs/env/lib/python3.9/site-packages/nibabel/arrayproxy.py:424, in ArrayProxy._get_scaled(self, dtype, slicer)
#     422     scl_inter = scl_inter.astype(use_dtype)
#     423 # Read array and upcast as necessary for big slopes, intercepts
# --> 424 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     425 if dtype is not None:
#     426     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File ~/miniforge3/envs/env/lib/python3.9/site-packages/nibabel/arrayproxy.py:394, in ArrayProxy._get_unscaled(self, slicer)
#     390 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     391     (), self._shape, False
#     392 ):
#     393     with self._get_fileobj() as fileobj, self._lock:
# --> 394         return array_from_file(
#     395             self._shape,
#     396             self._dtype,
#     397             fileobj,
#     398             offset=self._offset,
#     399             order=self.order,
#     400             mmap=self._mmap,
#     401         )
#     402 with self._get_fileobj() as fileobj:
#     403     return fileslice(
#     404         fileobj,
#     405         slicer,
#    (...)
#     410         lock=self._lock,
#     411     )
#
# File ~/miniforge3/envs/env/lib/python3.9/site-packages/nibabel/volumeutils.py:472, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     470     needs_copy = True
#     471 if n_bytes != n_read:
# --> 472     raise OSError(
#     473         f'Expected {n_bytes} bytes, got {n_read} bytes from '
#     474         f"{getattr(infile, 'name', 'object')}\n - could the file be damaged?"
#     475     )
#     476 arr: np.ndarray = np.ndarray(shape, in_dtype, buffer=data_bytes, order=order)
#     477 if needs_copy:
#
# OSError: Expected 6997412 bytes, got 6688416 bytes from /Users/jayantadey/data_MRI/sub-A00033849/mri/mwp1sub-A00033849_T1w.nii
#  - could the file be damaged?

# %%
X = np.array(X)
# Out:
# /var/folders/gv/wp457yys7h73m9dkm35g8l4r0000gn/T/ipykernel_3211/55319187.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
