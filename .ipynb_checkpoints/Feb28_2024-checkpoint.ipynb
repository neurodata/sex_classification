# %%
import pandas as  pd
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
from sklearn.ensemble import RandomForestClassifier
from sktree import ObliqueRandomForestClassifier, PatchObliqueRandomForestClassifier
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import random

# %%
df = pd.read_excel('/Users/jayantadey/data_MRI/subjects_age_sex_data_MRI.xlsx')
df.head()
# Out:
#                  ID      Age     Sex Dataset Dataset-ID
# 0  sub-ABIDE1050339  18.0000    MALE   ABIDE      50339
# 1  sub-ABIDE1050701  18.0000    MALE   ABIDE      50701
# 2  sub-ABIDE1050445  18.1383    MALE   ABIDE      50445
# 3  sub-ABIDE1050459  18.1547    MALE   ABIDE      50459
# 4  sub-ABIDE1050341  18.2000  FEMALE   ABIDE      50341

# %%
df_quality = pd.read_csv('/Users/jayantadey/data_MRI/QC_catreport.csv')
df_quality.head()
# Out:
#              sub Weighted average (IQR) Warning
# 0  sub-A00008326                  83.86       0
# 1  sub-A00008399                   83.3       0
# 2  sub-A00010893                   78.3       0
# 3  sub-A00013809                  79.36       0
# 4  sub-A00018030                  84.05       0

# %% [markdown]
# ### Load the mask

# %%
mask = nb.load('/Users/jayantadey/data_MRI/template_cat12/brainmask.nii').get_fdata()

# %%
slice=50
sliced_img = mask[:,:,slice]

fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.imshow(sliced_img)

ax.set_title('Mask (Traverse)', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Mask (Traverse)')

# %%
idx = np.where(mask.reshape(-1)>0)[0]

# %% [markdown]
# ### Load data and build (feature, label)

# %%
path = '/Users/jayantadey/data_MRI/'
subjects = os.listdir(path)
X = []
y = []
IDs = set(df['ID'])
quality_ID = set(df_quality['sub'])
for subject in tqdm(subjects):
    if subject in IDs and subject in quality_ID:
        #print(df[df['ID']==subject]['Sex'])
        IQR = list(df_quality[df_quality['sub']==subject]['Weighted average (IQR)'])[0]
        
        if IQR is np.nan:
            continue
            
        if IQR[-1] == '%':
            continue
        
        if float(IQR) < 60:
            continue
            
        gender = list(df[df['ID']==subject]['Sex'])
        
        if len(gender)>1:
            sex = int(gender[0]=='FEMALE')
        else:
            sex = int(gender=='FEMALE')
        
        current_file = os.path.join(path, subject)
        tmp = []
        save = True
        for file in glob.glob(current_file+'/mri/*'):
            try:
                img = nb.load(file).get_fdata()
                #print(img.shape)
                tmp.append(img.reshape(-1)[idx])
            except:
                save = False
                print(file,' corrupted')

        '''if len(tmp)<2:
            print(subject, ' has less files')'''
            
        if save and len(tmp)==2:
            X.append(np.array(tmp).reshape(1,-1))
            y.append(sex)
    
X = np.concatenate(X,axis=0)
# Out:
#  39%|█████████████████████████████████████████████████████████████████▋                                                                                                       | 5627/14469 [03:27<05:20, 27.62it/s]
# /Users/jayantadey/data_MRI/sub-HCA9086283/mri/mwp2sub-HCA9086283_T1w.nii.gz  corrupted
#  39%|█████████████████████████████████████████████████████████████████▊                                                                                                       | 5630/14469 [03:27<06:13, 23.64it/s]
# /Users/jayantadey/data_MRI/sub-OAS30102MRD0024/mri/mwp1sub-OAS30102MRD0024_T1w.nii.gz  corrupted
#  39%|██████████████████████████████████████████████████████████████████▌                                                                                                      | 5698/14469 [03:29<05:39, 25.85it/s]
# /Users/jayantadey/data_MRI/sub-DS004173212152/mri/mwp2sub-DS004173212152_T1w.nii.gz  corrupted
#  39%|██████████████████████████████████████████████████████████████████▋                                                                                                      | 5708/14469 [03:30<04:50, 30.15it/s]
# /Users/jayantadey/data_MRI/sub-AOMIC_0778/mri/mwp2sub-AOMIC_0778_T1w.nii.gz  corrupted
#  39%|██████████████████████████████████████████████████████████████████▋                                                                                                      | 5712/14469 [03:30<05:39, 25.80it/s]
# /Users/jayantadey/data_MRI/sub-HCPYA123521/mri/mwp1sub-HCPYA123521_T1w.nii.gz  corrupted
#  40%|██████████████████████████████████████████████████████████████████▊                                                                                                      | 5718/14469 [03:30<06:07, 23.82it/s]
# /Users/jayantadey/data_MRI/sub-A00051528/mri/mwp1sub-A00051528_T1w.nii.gz  corrupted
#  40%|██████████████████████████████████████████████████████████████████▊                                                                                                      | 5723/14469 [03:30<05:11, 28.08it/s]
# /Users/jayantadey/data_MRI/sub-A00028184/mri/mwp2sub-A00028184_T1w.nii.gz  corrupted
# /Users/jayantadey/data_MRI/sub-COBRE0040018/mri/mwp1sub-COBRE0040018_T1w.nii  corrupted
#  40%|██████████████████████████████████████████████████████████████████▉                                                                                                      | 5732/14469 [03:31<06:17, 23.16it/s]
# /Users/jayantadey/data_MRI/sub-OAS10256MR1/mri/mwp2sub-OAS10256MR1_T1w.nii.gz  corrupted
#  40%|███████████████████████████████████████████████████████████████████                                                                                                      | 5738/14469 [03:31<07:01, 20.72it/s]
# /Users/jayantadey/data_MRI/sub-WS032880/mri/mwp1sub-WS032880_T1w.nii.gz  corrupted
#  40%|███████████████████████████████████████████████████████████████████                                                                                                      | 5743/14469 [03:31<06:21, 22.90it/s]
# /Users/jayantadey/data_MRI/sub-HCA7253064/mri/mwp2sub-HCA7253064_T1w.nii.gz  corrupted
#  40%|███████████████████████████████████████████████████████████████████▉                                                                                                     | 5813/14469 [03:34<07:00, 20.57it/s]

# %%
len(X)
# Out:
# 525

# %% [markdown]
# ### Find the feature importance

# %%
reps = 10
sample_size_ratio = 0.6
feature_map_diff = np.zeros(X.shape[1], dtype=float)

for ii in tqdm(range(reps)):
    x_train, x_test, y_train, y_test = train_test_split(
                    X, y, train_size=sample_size_ratio,random_state=ii, stratify=y)
    total_sample = len(x_train)
    y_random = y_train.copy()
    random.shuffle(y_random)
    
    clf_random = RandomForestClassifier(n_estimators=100)
    clf = RandomForestClassifier(n_estimators=100)
    
    clf_random.fit(x_train,y_random)
    clf.fit(x_train,y_train)
    
    random_importance_map = clf_random.feature_importances_
    importance_map = clf.feature_importances_
    diff = importance_map - random_importance_map
    feature_idx = np.where(diff > 0)[0]
    map_diff = np.zeros(X.shape[1], dtype=float)
    map_diff[feature_idx] = 1
    
    feature_map_diff += map_diff

feature_map_diff /= reps
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [39:00<00:00, 234.03s/it]

# %%
slice = 50
demo_filepath_whitematter = '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp2sub-A00008326_T1w.nii'
demo_filepath_graymatter = '/Users/jayantadey/data_MRI/sub-A00008326/mri/mwp1sub-A00008326_T1w.nii'

img_whitematter = nb.load(demo_filepath_whitematter).get_fdata()
sliced_img_whitematter = img_whitematter[:,:,slice]

img_graymatter = nb.load(demo_filepath_graymatter).get_fdata()
sliced_img_graymatter = img_graymatter[:,:,slice]

# %%
brain_img = 0*np.ones((113*137*113), dtype=float)
brain_img[idx] = feature_map_diff[:len(idx)]
brain_img = brain_img.reshape(113,137,113)

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8))
ax[0].imshow(brain_img[:,:,50])
ax[1].imshow(sliced_img_graymatter)

ax[0].set_title('RF feature importance)', fontsize=20)
ax[1].set_title('White matter (Traverse)', fontsize=20)
# Out:
# Text(0.5, 1.0, 'White matter (Traverse)')

# %% [markdown]
# ### Train MORF

# %%
x_train, x_test, y_train, y_test = train_test_split(
                    X, y, train_size=sample_size_ratio,random_state=0, stratify=y)

clf = PatchObliqueRandomForestClassifier(n_estimators=100)
